# %%
import pandas as pd
import numpy as np
import scipy.sparse as sps
import matplotlib.pyplot as pyplot
import time
import RecSys2022.Utils.DataReader as dr


from Evaluation.Evaluator import EvaluatorHoldout
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample
from Utils.DataReader import load_urm#, load_icm, load_target
from Recommenders.SLIM.Cython.SLIM_BPR_Cython import UserSlimBPRRecommender
from Recommenders.IR_feature_weighting import okapi_BM_25
#from Recommenders.FactorizationMachines.LightFMRecommender import LightFMItemHybridRecommender
from Recommenders.SLIM.SLIMElasticNetRecommender import SLIMElasticNetRecommender
from Recommenders.GraphBased.RP3betaRecommender import UserRp3Recommender, RP3betaRecommender
from Recommenders.EASE_R.EASE_R_Recommender import EASE_R_Recommender
from Recommenders.SLIM.Cython.SLIM_BPR_Cython import SLIM_BPR_Cython
from Recommenders.MatrixFactorization.Cython.MatrixFactorizationImpressions_Cython import MatrixFactorization_FunkSVD_Cython

URM_all = dr.load_urm("../data/URMtries/RatingsBinary.csv")
URM_all_tanh = dr.load_urm("../data/URMtries/RatingsWithTanHCount.csv")
URM_all_tanh_type_len = dr.load_urm("../data/URMtries/RatingsWithTanHKnownTypeAndLength.csv")
ICM_tr = dr.load_icm("../data/data_ICM_type_truncated.csv")
URM_all_scores = sps.load_npz("URM_all_scores.npz")

URM_train = sps.load_npz("trainDefault.npz")
URM_train_TanH = sps.load_npz("trainTanH.npz")
URM_train_real = sps.load_npz("trainReal.npz")
URM_valid = sps.load_npz("validDefault.npz")
#evaluator_validation = EvaluatorHoldout(URM_valid, cutoff_list=[10])
stacked_URM = sps.vstack([URM_all, ICM_tr.T])
stacked_URM_TanH = sps.vstack([URM_all_tanh, ICM_tr.T])
stacked_URM_train = sps.vstack([URM_train, ICM_tr.T])
#20.42.95.202
evaluator_validation = EvaluatorHoldout(URM_valid, cutoff_list=[10])
# Out:
# EvaluatorHoldout: Ignoring 963 ( 2.3%) Users that have less than 1 test interactions
# RP3betaRecommender: Similarity column 24507 (100.0%), 2437.15 column/sec. Elapsed time 10.06 sec
# EvaluatorHoldout: Processed 40666 (100.0%) in 24.21 sec. Users per second: 1680
# 0.023799576339658426

# %% [markdown]
# # OKAPI bm25 if needed

# %%
URM_all_bm25 = URM_all.copy().astype(np.float32)
URM_all_bm25 = okapi_BM_25(URM_all_bm25)
URM_all_bm25 = URM_all_bm25.tocsr()

# %% [markdown]
# # Different Loss Hybrid class

# %%
from Recommenders.BaseRecommender import BaseRecommender

class DifferentLossScoresHybridRecommender2(BaseRecommender):
    """ ScoresHybridRecommender
    Hybrid of three predictions scores
    R = R1*alpha + R2*beta

    Class from Dacrema exercise modified by Antonio Ercolani
    The original took as input 2 recommender

    """

    RECOMMENDER_NAME = "DifferentLossScoresHybridRecommender"

    def __init__(self, URM_train, recommender_1, recommender_2):
        super(DifferentLossScoresHybridRecommender2, self).__init__(URM_train)

        self.URM_train = sps.csr_matrix(URM_train)
        self.recommender_1 = recommender_1
        self.recommender_2 = recommender_2

    def fit(self, alpha=0.5, beta=0.5):
        self.alpha = alpha
        self.beta = beta

    def _compute_item_score(self, user_id_array, items_to_compute = None):
        item_weights_1 = self.recommender_1._compute_item_score(user_id_array)
        item_weights_2 = self.recommender_2._compute_item_score(user_id_array)

        item_weights = item_weights_1 * self.alpha + item_weights_2 * self.beta

        return item_weights

from Recommenders.BaseRecommender import BaseRecommender

class DifferentLossScoresHybridRecommender4(BaseRecommender):
    """ ScoresHybridRecommender
    Hybrid of three predictions scores
    R = R1*alpha + R2*beta

    Class from Dacrema exercise modified by Antonio Ercolani
    The original took as input 2 recommender

    """

    RECOMMENDER_NAME = "DifferentLossScoresHybridRecommender"

    def __init__(self, URM_train, recommender_1, recommender_2, recommender_3, recommender_4):
        super(DifferentLossScoresHybridRecommender4, self).__init__(URM_train)

        self.URM_train = sps.csr_matrix(URM_train)
        self.recommender_1 = recommender_1
        self.recommender_2 = recommender_2
        self.recommender_3 = recommender_3
        self.recommender_4 = recommender_4

    def fit(self, alpha=0.5, beta=0.5, gamma=0.5, delta = 0.5):
        self.alpha = alpha
        self.beta = beta
        self.gamma = gamma
        self.delta = delta

    def _compute_item_score(self, user_id_array, items_to_compute = None):
        item_weights_1 = self.recommender_1._compute_item_score(user_id_array)
        item_weights_2 = self.recommender_2._compute_item_score(user_id_array)
        item_weights_3 = self.recommender_3._compute_item_score(user_id_array)
        item_weights_4 = self.recommender_4._compute_item_score(user_id_array)

        item_weights = item_weights_1 * self.alpha + item_weights_2 * self.beta + item_weights_3 * self.gamma + item_weights_4 * self.delta

        return item_weights

class DifferentLossScoresHybridRecommender3(BaseRecommender):
    """ ScoresHybridRecommender
    Hybrid of three predictions scores
    R = R1*alpha + R2*beta

    Class from Dacrema exercise modified by Antonio Ercolani
    The original took as input 2 recommender

    """

    RECOMMENDER_NAME = "DifferentLossScoresHybridRecommender"

    def __init__(self, URM_train, recommender_1, recommender_2, recommender_3):
        super(DifferentLossScoresHybridRecommender3, self).__init__(URM_train)

        self.URM_train = sps.csr_matrix(URM_train)
        self.recommender_1 = recommender_1
        self.recommender_2 = recommender_2
        self.recommender_3 = recommender_3

    def fit(self, alpha=0.5, beta=0.5, gamma=0.5):
        self.alpha = alpha
        self.beta = beta
        self.gamma = gamma

    def _compute_item_score(self, user_id_array, items_to_compute = None):
        item_weights_1 = self.recommender_1._compute_item_score(user_id_array)
        item_weights_2 = self.recommender_2._compute_item_score(user_id_array)
        item_weights_3 = self.recommender_3._compute_item_score(user_id_array)

        item_weights = item_weights_1 * self.alpha + item_weights_2 * self.beta + item_weights_3 * self.gamma

        return item_weights

    def save_model(self, folder_path, file_name = None):
        pass

# %%
import os

output_folder_path = "result_experiments/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

n_cases = 500
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"
cutoff_to_optimize = 10

# %%
from skopt.space import Real, Integer, Categorical

hyperparameters_range_dictionary_SSLIM = {
    "topK": Categorical([950]),
    "l1_ratio": Categorical([0.004999999999999999]),
    "alpha": Categorical([0.0015746723778813712]),
    "nof_icms": Integer(low=1, high=4),
    "icm_coeff": Real(low=0.25, high=4)
}

hyperparameters_range_dictionary_SLIM_focus = {
    "topK": Integer(450, 1000),
    "l1_ratio": Real(low = 0.0001, high = 0.001, prior = 'log-uniform'),
    "alpha": Real(low = 0.01, high = 0.1, prior = 'uniform'),
}

hyperparameters_range_dictionary_SLIM = {
    "topK": Integer(5, 1000),
    "l1_ratio": Real(low = 1e-5, high = 1.0, prior = 'log-uniform'),
    "alpha": Real(low = 1e-3, high = 1.0, prior = 'uniform'),
}

hyperparameters_range_dictionary_EASE = {
    "topK": Integer(low=10, high=2000, prior="uniform"),
    "normalize_matrix": Categorical([False]),
    "l2_norm": Real(low = 1e0, high = 1e7, prior = 'log-uniform'),
}

hyperparameters_range_dictionary_RP3 = {
    "topK": Integer(175, 230),
    "alpha": Real(low = 0.2, high = 0.5, prior = 'uniform'),
    "beta": Real(low = 0.3, high = 0.6, prior = 'uniform'),
    "normalize_similarity": Categorical([True]),
    "stacked": Categorical([True]),
    "icm_coeff": Real(low=0.4, high=0.6, prior="uniform")
}

hyperparameters_range_dictionary_SuperiorRP3 = {
    "alpha": Real(low = 0, high = 100, prior = 'uniform'),
    "beta": Real(low = 0, high = 100, prior = 'uniform')
}

hyperparameters_range_dictionary_SLIMBPR = {
    "topK": Integer(20, 550),
    "epochs": Categorical([1500]),
    "symmetric": Categorical([True]),
    "sgd_mode": Categorical(["sgd", "adagrad"]),
    "lambda_i": Real(low = 1e-5, high = 1e-4, prior = 'log-uniform'),
    "lambda_j": Real(low = 1e-6, high = 1e-4, prior = 'log-uniform'),
    "learning_rate": Real(low = 0.05, high = 0.15, prior = 'log-uniform'),
    "random_seed": Categorical([42]),
    "stack": Categorical([True]),
    "icm_coeff": Real(low=0.5, high=2, prior="uniform"),
    "normalize_similarity": Categorical([True, False])
}

hyperparameters_range_dictionary_FM = {
    "epochs": Categorical([300]),
    "n_components": Integer(1, 200),
    "loss": Categorical(['bpr', 'warp', 'warp-kos']),
    "sgd_mode": Categorical(['adagrad', 'adadelta']),
    "learning_rate": Real(low = 1e-6, high = 1e-1, prior = 'log-uniform'),
    "item_alpha": Real(low = 1e-5, high = 1e-2, prior = 'log-uniform'),
    "user_alpha": Real(low = 1e-5, high = 1e-2, prior = 'log-uniform'),
}

hyperparameters_range_dictionary_hybrid = {
    "alpha": Real(low = 0, high = 100, prior = 'uniform'),
    "beta": Real(low = 0, high = 100, prior = 'uniform'),
    #"gamma": Real(low = 0, high = 100, prior = 'uniform'),
    #"delta": Real(low = 0, high = 30, prior = 'uniform'),
    #"topK": Integer(low=400, high=700, prior="uniform")
}

hyperparameters_range_dictionary_KNN = {
    "similarity": Categorical(['cosine', 'jaccard', "asymmetric", "dice", "tversky"]),
    "topK": Integer(10, 500),
    "shrink": Integer(1, 200),
    "normalize": Categorical([True, False]),
    "feature_weighting": Categorical(["none", "BM25", "TF-IDF"])
}

hyperparameters_range_dictionary_KNN_subset = {
    "similarity": Categorical(['cosine', 'jaccard']),
    "topK": Integer(35, 70),
    "shrink": Integer(140, 180),
    "normalize": Categorical([True]),
    "feature_weighting": Categorical(["TF-IDF"])
}

hyperparameters_range_dictionary_NMF = {
    "num_factors": Integer(1, 350),
    "solver": Categorical(["coordinate_descent", "multiplicative_update"]),
    "init_type": Categorical(["random", "nndsvda"]),
    "beta_loss": Categorical(["frobenius"]),
    "random_seed": Categorical([42])
}

#learning_rate=1e-5, beta=1, epochs=80, l1_reg=3e-5
hyperparameters_range_dictionary_SLIMRMSE = {
    "learning_rate": Real(low=1e-5, high=1e-3, prior="uniform"),
    "beta": Categorical([1]),
    "epochs": Integer(low=1, high=2, prior="uniform"),
    "l1_reg": Real(low=1e-5, high=1e-3, prior="uniform")
}

hyperparameters_range_dictionary_MF_IMPR = {
    "sgd_mode": Categorical(["sgd", "adagrad", "adam"]),
    "epochs": Categorical([150]),
    "use_bias": Categorical([True, False]),
    "batch_size": Categorical([1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]),
    "num_factors": Integer(1, 200),
    "item_reg": Real(low = 1e-8, high = 1e-4, prior = 'log-uniform'),
    "user_reg": Real(low = 1e-8, high = 1e-4, prior = 'log-uniform'),
    "positive_reg": Real(low = 1e-8, high = 1e-4, prior = 'log-uniform'),
    "negative_reg": Real(low = 1e-8, high = 1e-4, prior = 'log-uniform'),
    "learning_rate": Real(low = 1e-4, high = 1e-1, prior = 'log-uniform'),
    "negative_interactions_quota": Real(low = 0.0, high = 0.5, prior = 'uniform'),
    "random_seed": Categorical([42])
}

# %%
from HyperparameterTuning.SearchBayesianSkopt import SearchBayesianSkopt
from RecSys2022.Recommenders.EASE_R import EASE_R_Recommender
from Recommenders.KNN.UserKNNCFRecommender import UserKNNCFRecommender
from Recommenders.KNN.ItemKNNCFRecommender import ItemKNNCFRecommender
from Recommenders.KNN.ItemKNNCBFRecommender import ItemKNNCBFRecommender
from Recommenders.MatrixFactorization.NMFRecommender import NMFRecommender
from Recommenders.SLIM.SSLIMMSE import SSLIMRMSERecommender
recommender_class = DifferentLossScoresHybridRecommender2
#create a bayesian optimizer object, we pass the recommender and the evaluator
hyperparameterSearch = SearchBayesianSkopt(recommender_class,
                                           evaluator_validation=evaluator_validation)

# %%
slimbpr_bin = SLIM_BPR_Cython(URM_train)
slimbpr_bin.load_model("C:\\Users\\Andrea\\AppData\\Roaming\\JetBrains\\DataSpell2022.2\\projects\\RecSys2022\\data\\saved_models\\", "SLIMBPR_BIN_TRAIN")
slimbpr_bin.W_sparse = slimbpr_bin.W_sparse.get('W_sparse')

stacked_URM_TanH_train = sps.vstack([URM_train_TanH, ICM_tr.T])

slimbpr_tanh = SLIM_BPR_Cython(stacked_URM_TanH_train)
slimbpr_tanh.load_model("C:\\Users\\Andrea\\AppData\\Roaming\\JetBrains\\DataSpell2022.2\\projects\\RecSys2022\\data\\saved_models\\", "SLIMBPR_TANH_TRAIN_STACKED")
slimbpr_tanh.W_sparse = slimbpr_tanh.W_sparse.get('W_sparse')
# Out:
# SLIM_BPR_Recommender: Loading model from file 'C:\Users\Andrea\AppData\Roaming\JetBrains\DataSpell2022.2\projects\RecSys2022\data\saved_models\SLIMBPR_BIN_TRAIN'
#   (0, 18)	0.2626935
#   (0, 320)	0.2029069
#   (0, 329)	0.24602552
#   (0, 822)	0.30130786
#   (0, 1256)	0.24716282
#   (0, 1451)	0.22538476
#   (0, 1507)	0.239857
#   (0, 1837)	0.20446162
#   (0, 2185)	0.21781924
#   (0, 2207)	0.24833192
#   (0, 2213)	0.23224708
#   (0, 2882)	0.21117224
#   (0, 2883)	0.22454911
#   (0, 3606)	0.25452262
#   (0, 4228)	0.27893725
#   (0, 4553)	0.2630109
#   (0, 4564)	0.2305793
#   (0, 4644)	0.22434404
#   (0, 4794)	0.27656624
#   (0, 4969)	0.23842192
#   (0, 5257)	0.2579844
#   (0, 5414)	0.250959
#   (0, 5523)	0.282262
#   (0, 5639)	0.21033141
#   (0, 5723)	0.21987584
#   :	:
#   (24506, 17636)	0.22373872
#   (24506, 17644)	0.28662798
#   (24506, 17928)	0.28674176
#   (24506, 18082)	0.27270553
#   (24506, 18159)	0.21880895
#   (24506, 19225)	0.35958183
#   (24506, 19638)	0.31348163
#   (24506, 19967)	0.4079425
#   (24506, 20034)	0.27222744
#   (24506, 20111)	0.2689342
#   (24506, 20555)	0.42460153
#   (24506, 21368)	0.28633127
#   (24506, 21394)	0.24002929
#   (24506, 21647)	0.27094293
#   (24506, 21703)	0.25434852
#   (24506, 22388)	0.4095013
#   (24506, 22548)	0.2683324
#   (24506, 22574)	0.23260827
#   (24506, 23594)	0.2501336
#   (24506, 23823)	0.35540292
#   (24506, 23930)	0.34819117
#   (24506, 23974)	0.34584042
#   (24506, 24144)	0.4521377
#   (24506, 24146)	0.26840433
#   (24506, 24317)	0.26847076
# {'W_sparse': <24507x24507 sparse matrix of type '<class 'numpy.float32'>'
# 	with 2111543 stored elements in Compressed Sparse Row format>}
# SLIM_BPR_Recommender: URM Detected 3 ( 0.0%) users with no interactions.
# SLIM_BPR_Recommender: Loading model from file 'C:\Users\Andrea\AppData\Roaming\JetBrains\DataSpell2022.2\projects\RecSys2022\data\saved_models\SLIMBPR_TANH_TRAIN_STACKED'
#   (0, 18)	0.010380953
#   (0, 171)	0.0060237
#   (0, 320)	0.007842606
#   (0, 329)	0.010216848
#   (0, 623)	0.004206947
#   (0, 730)	0.0055352123
#   (0, 822)	0.012195141
#   (0, 1256)	0.009920229
#   (0, 1451)	0.008361899
#   (0, 1507)	0.01088402
#   (0, 1523)	0.007987255
#   (0, 1663)	0.008413317
#   (0, 1709)	0.005355887
#   (0, 1836)	0.008994087
#   (0, 1837)	0.0079228375
#   (0, 2093)	0.0059212227
#   (0, 2185)	0.008509567
#   (0, 2207)	0.0095437225
#   (0, 2213)	0.011559011
#   (0, 2440)	0.004808308
#   (0, 2446)	0.007007236
#   (0, 2882)	0.008644428
#   (0, 2883)	0.008507985
#   (0, 2964)	0.0041859364
#   (0, 2988)	0.00458832
#   :	:
#   (24506, 21368)	0.011806801
#   (24506, 21394)	0.009075001
#   (24506, 21429)	0.008409143
#   (24506, 21647)	0.010471464
#   (24506, 21703)	0.010439528
#   (24506, 21770)	0.0039893347
#   (24506, 22168)	0.011158903
#   (24506, 22388)	0.024178624
#   (24506, 22482)	0.0037520688
#   (24506, 22548)	0.011966908
#   (24506, 22574)	0.011676331
#   (24506, 23047)	0.010288805
#   (24506, 23121)	0.0052564456
#   (24506, 23594)	0.010874668
#   (24506, 23823)	0.019762557
#   (24506, 23863)	0.004731964
#   (24506, 23889)	0.005899191
#   (24506, 23917)	0.011250975
#   (24506, 23930)	0.017623072
#   (24506, 23974)	0.020352447
#   (24506, 24002)	0.0046440135
#   (24506, 24144)	0.022142645
#   (24506, 24146)	0.01195215
#   (24506, 24317)	0.013731322
#   (24506, 24378)	0.002747268
# {'W_sparse': <24507x24507 sparse matrix of type '<class 'numpy.float32'>'
# 	with 5281054 stored elements in Compressed Sparse Row format>}

# %%
from HyperparameterTuning.SearchAbstractClass import SearchInputRecommenderArgs

#provide data needed to create instance of model (one on URM_train, the other on URM_all)
recommender_input_args = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [stacked_URM_train, slimbpr_bin, slimbpr_tanh],
    #CONSTRUCTOR_POSITIONAL_ARGS = [stacked_URM_train],
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = {},
    #EARLYSTOPPING_KEYWORD_ARGS = earlystopping_keywargs,
)

# %%
hyperparameterSearch.search(recommender_input_args = recommender_input_args,
                            hyperparameter_search_space = hyperparameters_range_dictionary_hybrid,
                            n_cases = n_cases,
                            n_random_starts = n_random_starts,
                            save_model = "no",
                            output_folder_path = output_folder_path, # Where to save the results
                            output_file_name_root = recommender_class.RECOMMENDER_NAME, # How to call the files
                            metric_to_optimize = metric_to_optimize,
                            cutoff_to_optimize = cutoff_to_optimize,
                            )
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 23.438254877308523, 'beta': 91.96624444591818}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 28.50 sec. Users per second: 1427
# SearchBayesianSkopt: New best config found. Config 0: {'alpha': 23.438254877308523, 'beta': 91.96624444591818} - results: PRECISION: 0.0490852, PRECISION_RECALL_MIN_DEN: 0.0827817, RECALL: 0.0777111, MAP: 0.0238072, MAP_MIN_DEN: 0.0394610, MRR: 0.1657171, NDCG: 0.0794636, F1: 0.0601669, HIT_RATE: 0.3368416, ARHR_ALL_HITS: 0.1972251, NOVELTY: 0.0042560, AVERAGE_POPULARITY: 0.2222107, DIVERSITY_MEAN_INTER_LIST: 0.9242714, DIVERSITY_HERFINDAHL: 0.9924249, COVERAGE_ITEM: 0.4848411, COVERAGE_ITEM_HIT: 0.0445587, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3290495, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0316541, SHANNON_ENTROPY: 8.8290805, RATIO_DIVERSITY_HERFINDAHL: 0.9927439, RATIO_DIVERSITY_GINI: 0.0614066, RATIO_SHANNON_ENTROPY: 0.6531036, RATIO_AVERAGE_POPULARITY: 4.3541752, RATIO_NOVELTY: 0.2395448,
#
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 28.7539
# Function value obtained: -0.0238
# Current minimum: -0.0238
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 76.72325897637997, 'beta': 39.303200542368245}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 29.39 sec. Users per second: 1384
# SearchBayesianSkopt: New best config found. Config 1: {'alpha': 76.72325897637997, 'beta': 39.303200542368245} - results: PRECISION: 0.0495672, PRECISION_RECALL_MIN_DEN: 0.0831038, RECALL: 0.0778962, MAP: 0.0239734, MAP_MIN_DEN: 0.0395370, MRR: 0.1659358, NDCG: 0.0797249, F1: 0.0605836, HIT_RATE: 0.3382678, ARHR_ALL_HITS: 0.1980483, NOVELTY: 0.0043622, AVERAGE_POPULARITY: 0.1943685, DIVERSITY_MEAN_INTER_LIST: 0.9451082, DIVERSITY_HERFINDAHL: 0.9945085, COVERAGE_ITEM: 0.5271555, COVERAGE_ITEM_HIT: 0.0494553, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3304427, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0390101, SHANNON_ENTROPY: 9.2492908, RATIO_DIVERSITY_HERFINDAHL: 0.9948282, RATIO_DIVERSITY_GINI: 0.0756768, RATIO_SHANNON_ENTROPY: 0.6841874, RATIO_AVERAGE_POPULARITY: 3.8086139, RATIO_NOVELTY: 0.2455222,
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 29.6258
# Function value obtained: -0.0240
# Current minimum: -0.0240
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 47.35664950175992, 'beta': 28.53481884008741}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 29.42 sec. Users per second: 1382
# SearchBayesianSkopt: New best config found. Config 2: {'alpha': 47.35664950175992, 'beta': 28.53481884008741} - results: PRECISION: 0.0495697, PRECISION_RECALL_MIN_DEN: 0.0831315, RECALL: 0.0779226, MAP: 0.0239809, MAP_MIN_DEN: 0.0395472, MRR: 0.1660044, NDCG: 0.0797460, F1: 0.0605934, HIT_RATE: 0.3384892, ARHR_ALL_HITS: 0.1981150, NOVELTY: 0.0043585, AVERAGE_POPULARITY: 0.1952754, DIVERSITY_MEAN_INTER_LIST: 0.9445191, DIVERSITY_HERFINDAHL: 0.9944496, COVERAGE_ITEM: 0.5257681, COVERAGE_ITEM_HIT: 0.0492512, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3306589, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0387377, SHANNON_ENTROPY: 9.2351829, RATIO_DIVERSITY_HERFINDAHL: 0.9947692, RATIO_DIVERSITY_GINI: 0.0751483, RATIO_SHANNON_ENTROPY: 0.6831438, RATIO_AVERAGE_POPULARITY: 3.8263844, RATIO_NOVELTY: 0.2453124,
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 29.6836
# Function value obtained: -0.0240
# Current minimum: -0.0240
# Iteration No: 4 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 65.74799225026871, 'beta': 32.83755020670886}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 30.16 sec. Users per second: 1348
# SearchBayesianSkopt: Config 3 is suboptimal. Config: {'alpha': 65.74799225026871, 'beta': 32.83755020670886} - results: PRECISION: 0.0495672, PRECISION_RECALL_MIN_DEN: 0.0830841, RECALL: 0.0778784, MAP: 0.0239705, MAP_MIN_DEN: 0.0395308, MRR: 0.1658990, NDCG: 0.0797137, F1: 0.0605782, HIT_RATE: 0.3382432, ARHR_ALL_HITS: 0.1980149, NOVELTY: 0.0043627, AVERAGE_POPULARITY: 0.1942485, DIVERSITY_MEAN_INTER_LIST: 0.9451853, DIVERSITY_HERFINDAHL: 0.9945162, COVERAGE_ITEM: 0.5273187, COVERAGE_ITEM_HIT: 0.0494553, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3304187, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0390468, SHANNON_ENTROPY: 9.2511136, RATIO_DIVERSITY_HERFINDAHL: 0.9948359, RATIO_DIVERSITY_GINI: 0.0757480, RATIO_SHANNON_ENTROPY: 0.6843222, RATIO_AVERAGE_POPULARITY: 3.8062624, RATIO_NOVELTY: 0.2455498,
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 30.3763
# Function value obtained: -0.0240
# Current minimum: -0.0240
# Iteration No: 5 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 60.10757860821593, 'beta': 30.675840060353426}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 29.25 sec. Users per second: 1390
# SearchBayesianSkopt: Config 4 is suboptimal. Config: {'alpha': 60.10757860821593, 'beta': 30.675840060353426} - results: PRECISION: 0.0495746, PRECISION_RECALL_MIN_DEN: 0.0831122, RECALL: 0.0779031, MAP: 0.0239743, MAP_MIN_DEN: 0.0395373, MRR: 0.1659332, NDCG: 0.0797288, F1: 0.0605912, HIT_RATE: 0.3382924, ARHR_ALL_HITS: 0.1980517, NOVELTY: 0.0043623, AVERAGE_POPULARITY: 0.1943501, DIVERSITY_MEAN_INTER_LIST: 0.9451208, DIVERSITY_HERFINDAHL: 0.9945098, COVERAGE_ITEM: 0.5271963, COVERAGE_ITEM_HIT: 0.0494553, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3304667, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0390148, SHANNON_ENTROPY: 9.2495177, RATIO_DIVERSITY_HERFINDAHL: 0.9948294, RATIO_DIVERSITY_GINI: 0.0756860, RATIO_SHANNON_ENTROPY: 0.6842041, RATIO_AVERAGE_POPULARITY: 3.8082522, RATIO_NOVELTY: 0.2455255,
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 29.4939
# Function value obtained: -0.0240
# Current minimum: -0.0240
# Iteration No: 6 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 52.06182627516968, 'beta': 22.718596970491163}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 30.55 sec. Users per second: 1331
# SearchBayesianSkopt: Config 5 is suboptimal. Config: {'alpha': 52.06182627516968, 'beta': 22.718596970491163} - results: PRECISION: 0.0495451, PRECISION_RECALL_MIN_DEN: 0.0830258, RECALL: 0.0778256, MAP: 0.0239598, MAP_MIN_DEN: 0.0395084, MRR: 0.1659018, NDCG: 0.0796818, F1: 0.0605457, HIT_RATE: 0.3382678, ARHR_ALL_HITS: 0.1979746, NOVELTY: 0.0043654, AVERAGE_POPULARITY: 0.1935993, DIVERSITY_MEAN_INTER_LIST: 0.9456075, DIVERSITY_HERFINDAHL: 0.9945584, COVERAGE_ITEM: 0.5283796, COVERAGE_ITEM_HIT: 0.0496185, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3304427, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0392489, SHANNON_ENTROPY: 9.2611927, RATIO_DIVERSITY_HERFINDAHL: 0.9948781, RATIO_DIVERSITY_GINI: 0.0761401, RATIO_SHANNON_ENTROPY: 0.6850678, RATIO_AVERAGE_POPULARITY: 3.7935402, RATIO_NOVELTY: 0.2457008,
#
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 30.7651
# Function value obtained: -0.0240
# Current minimum: -0.0240
# Iteration No: 7 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 12.231351237575153, 'beta': 6.358717011873151}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 29.53 sec. Users per second: 1377
# SearchBayesianSkopt: Config 6 is suboptimal. Config: {'alpha': 12.231351237575153, 'beta': 6.358717011873151} - results: PRECISION: 0.0495672, PRECISION_RECALL_MIN_DEN: 0.0831031, RECALL: 0.0778933, MAP: 0.0239749, MAP_MIN_DEN: 0.0395396, MRR: 0.1659413, NDCG: 0.0797276, F1: 0.0605827, HIT_RATE: 0.3382924, ARHR_ALL_HITS: 0.1980566, NOVELTY: 0.0043619, AVERAGE_POPULARITY: 0.1944426, DIVERSITY_MEAN_INTER_LIST: 0.9450599, DIVERSITY_HERFINDAHL: 0.9945037, COVERAGE_ITEM: 0.5269923, COVERAGE_ITEM_HIT: 0.0494553, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3304667, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0389798, SHANNON_ENTROPY: 9.2480795, RATIO_DIVERSITY_HERFINDAHL: 0.9948233, RATIO_DIVERSITY_GINI: 0.0756181, RATIO_SHANNON_ENTROPY: 0.6840978, RATIO_AVERAGE_POPULARITY: 3.8100650, RATIO_NOVELTY: 0.2455043,
#
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 29.7573
# Function value obtained: -0.0240
# Current minimum: -0.0240
# Iteration No: 8 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 42.21861770086961, 'beta': 2.3930800558086838}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 29.23 sec. Users per second: 1391
# SearchBayesianSkopt: Config 7 is suboptimal. Config: {'alpha': 42.21861770086961, 'beta': 2.3930800558086838} - results: PRECISION: 0.0494885, PRECISION_RECALL_MIN_DEN: 0.0828714, RECALL: 0.0776878, MAP: 0.0239346, MAP_MIN_DEN: 0.0394533, MRR: 0.1657928, NDCG: 0.0795734, F1: 0.0604618, HIT_RATE: 0.3383170, ARHR_ALL_HITS: 0.1978015, NOVELTY: 0.0043830, AVERAGE_POPULARITY: 0.1893502, DIVERSITY_MEAN_INTER_LIST: 0.9483033, DIVERSITY_HERFINDAHL: 0.9948280, COVERAGE_ITEM: 0.5346228, COVERAGE_ITEM_HIT: 0.0504754, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3304908, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0405804, SHANNON_ENTROPY: 9.3271833, RATIO_DIVERSITY_HERFINDAHL: 0.9951478, RATIO_DIVERSITY_GINI: 0.0787232, RATIO_SHANNON_ENTROPY: 0.6899492, RATIO_AVERAGE_POPULARITY: 3.7102808, RATIO_NOVELTY: 0.2466912,
#
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 29.4754
# Function value obtained: -0.0239
# Current minimum: -0.0240
# Iteration No: 9 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 45.19232974893228, 'beta': 15.502301531662436}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 29.43 sec. Users per second: 1382
# SearchBayesianSkopt: Config 8 is suboptimal. Config: {'alpha': 45.19232974893228, 'beta': 15.502301531662436} - results: PRECISION: 0.0494984, PRECISION_RECALL_MIN_DEN: 0.0829607, RECALL: 0.0777775, MAP: 0.0239399, MAP_MIN_DEN: 0.0394630, MRR: 0.1657955, NDCG: 0.0796163, F1: 0.0604963, HIT_RATE: 0.3382924, ARHR_ALL_HITS: 0.1978350, NOVELTY: 0.0043696, AVERAGE_POPULARITY: 0.1925668, DIVERSITY_MEAN_INTER_LIST: 0.9462813, DIVERSITY_HERFINDAHL: 0.9946258, COVERAGE_ITEM: 0.5298894, COVERAGE_ITEM_HIT: 0.0497409, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3304667, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0395804, SHANNON_ENTROPY: 9.2772298, RATIO_DIVERSITY_HERFINDAHL: 0.9949455, RATIO_DIVERSITY_GINI: 0.0767832, RATIO_SHANNON_ENTROPY: 0.6862541, RATIO_AVERAGE_POPULARITY: 3.7733102, RATIO_NOVELTY: 0.2459376,
#
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 29.6502
# Function value obtained: -0.0239
# Current minimum: -0.0240
# Iteration No: 10 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 65.34407781851408, 'beta': 13.612151296337762}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 29.54 sec. Users per second: 1377
# SearchBayesianSkopt: Config 9 is suboptimal. Config: {'alpha': 65.34407781851408, 'beta': 13.612151296337762} - results: PRECISION: 0.0495402, PRECISION_RECALL_MIN_DEN: 0.0829842, RECALL: 0.0777962, MAP: 0.0239451, MAP_MIN_DEN: 0.0394757, MRR: 0.1657810, NDCG: 0.0796310, F1: 0.0605332, HIT_RATE: 0.3384892, ARHR_ALL_HITS: 0.1978358, NOVELTY: 0.0043759, AVERAGE_POPULARITY: 0.1910527, DIVERSITY_MEAN_INTER_LIST: 0.9472488, DIVERSITY_HERFINDAHL: 0.9947226, COVERAGE_ITEM: 0.5323377, COVERAGE_ITEM_HIT: 0.0501897, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3306589, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0400596, SHANNON_ENTROPY: 9.3008079, RATIO_DIVERSITY_HERFINDAHL: 0.9950423, RATIO_DIVERSITY_GINI: 0.0777127, RATIO_SHANNON_ENTROPY: 0.6879982, RATIO_AVERAGE_POPULARITY: 3.7436415, RATIO_NOVELTY: 0.2462903,
#
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 29.7689
# Function value obtained: -0.0239
# Current minimum: -0.0240
# Iteration No: 11 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 80.645880860137, 'beta': 61.44442797724323}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 29.37 sec. Users per second: 1384
# SearchBayesianSkopt: Config 10 is suboptimal. Config: {'alpha': 80.645880860137, 'beta': 61.44442797724323} - results: PRECISION: 0.0496213, PRECISION_RECALL_MIN_DEN: 0.0832060, RECALL: 0.0779950, MAP: 0.0239752, MAP_MIN_DEN: 0.0395338, MRR: 0.1658548, NDCG: 0.0797517, F1: 0.0606539, HIT_RATE: 0.3386613, ARHR_ALL_HITS: 0.1980067, NOVELTY: 0.0043516, AVERAGE_POPULARITY: 0.1969838, DIVERSITY_MEAN_INTER_LIST: 0.9433845, DIVERSITY_HERFINDAHL: 0.9943361, COVERAGE_ITEM: 0.5231975, COVERAGE_ITEM_HIT: 0.0489656, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3308271, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0382188, SHANNON_ENTROPY: 9.2087753, RATIO_DIVERSITY_HERFINDAHL: 0.9946557, RATIO_DIVERSITY_GINI: 0.0741418, RATIO_SHANNON_ENTROPY: 0.6811903, RATIO_AVERAGE_POPULARITY: 3.8598592, RATIO_NOVELTY: 0.2449251,
#
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 29.6008
# Function value obtained: -0.0240
# Current minimum: -0.0240
# Iteration No: 12 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 86.37290297907255, 'beta': 48.362942520690744}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 29.42 sec. Users per second: 1382
# SearchBayesianSkopt: Config 11 is suboptimal. Config: {'alpha': 86.37290297907255, 'beta': 48.362942520690744} - results: PRECISION: 0.0495647, PRECISION_RECALL_MIN_DEN: 0.0831185, RECALL: 0.0779069, MAP: 0.0239806, MAP_MIN_DEN: 0.0395448, MRR: 0.1659653, NDCG: 0.0797352, F1: 0.0605850, HIT_RATE: 0.3383170, ARHR_ALL_HITS: 0.1980886, NOVELTY: 0.0043601, AVERAGE_POPULARITY: 0.1948596, DIVERSITY_MEAN_INTER_LIST: 0.9447910, DIVERSITY_HERFINDAHL: 0.9944768, COVERAGE_ITEM: 0.5262578, COVERAGE_ITEM_HIT: 0.0494145, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3304908, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0388396, SHANNON_ENTROPY: 9.2412570, RATIO_DIVERSITY_HERFINDAHL: 0.9947964, RATIO_DIVERSITY_GINI: 0.0753461, RATIO_SHANNON_ENTROPY: 0.6835931, RATIO_AVERAGE_POPULARITY: 3.8182362, RATIO_NOVELTY: 0.2454040,
#
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 29.6330
# Function value obtained: -0.0240
# Current minimum: -0.0240
# Iteration No: 13 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 35.02962943855735, 'beta': 98.13032815450671}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 30.22 sec. Users per second: 1346
# SearchBayesianSkopt: Config 12 is suboptimal. Config: {'alpha': 35.02962943855735, 'beta': 98.13032815450671} - results: PRECISION: 0.0493238, PRECISION_RECALL_MIN_DEN: 0.0829602, RECALL: 0.0778343, MAP: 0.0238805, MAP_MIN_DEN: 0.0394980, MRR: 0.1658956, NDCG: 0.0796108, F1: 0.0603828, HIT_RATE: 0.3381449, ARHR_ALL_HITS: 0.1976469, NOVELTY: 0.0042841, AVERAGE_POPULARITY: 0.2145999, DIVERSITY_MEAN_INTER_LIST: 0.9305171, DIVERSITY_HERFINDAHL: 0.9930494, COVERAGE_ITEM: 0.4966744, COVERAGE_ITEM_HIT: 0.0458644, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3303226, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0335649, SHANNON_ENTROPY: 8.9443700, RATIO_DIVERSITY_HERFINDAHL: 0.9933686, RATIO_DIVERSITY_GINI: 0.0651136, RATIO_SHANNON_ENTROPY: 0.6616318, RATIO_AVERAGE_POPULARITY: 4.2050443, RATIO_NOVELTY: 0.2411261,
#
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 30.4481
# Function value obtained: -0.0239
# Current minimum: -0.0240
# Iteration No: 14 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 18.046657662303147, 'beta': 89.17078741604088}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 29.86 sec. Users per second: 1362
# SearchBayesianSkopt: Config 13 is suboptimal. Config: {'alpha': 18.046657662303147, 'beta': 89.17078741604088} - results: PRECISION: 0.0489131, PRECISION_RECALL_MIN_DEN: 0.0826488, RECALL: 0.0776182, MAP: 0.0236894, MAP_MIN_DEN: 0.0393270, MRR: 0.1650245, NDCG: 0.0792163, F1: 0.0600096, HIT_RATE: 0.3362268, ARHR_ALL_HITS: 0.1963309, NOVELTY: 0.0042346, AVERAGE_POPULARITY: 0.2280932, DIVERSITY_MEAN_INTER_LIST: 0.9191358, DIVERSITY_HERFINDAHL: 0.9919113, COVERAGE_ITEM: 0.4760681, COVERAGE_ITEM_HIT: 0.0437834, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3284489, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0302840, SHANNON_ENTROPY: 8.7392045, RATIO_DIVERSITY_HERFINDAHL: 0.9922301, RATIO_DIVERSITY_GINI: 0.0587488, RATIO_SHANNON_ENTROPY: 0.6464553, RATIO_AVERAGE_POPULARITY: 4.4694413, RATIO_NOVELTY: 0.2383401,
#
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 30.0931
# Function value obtained: -0.0237
# Current minimum: -0.0240
# Iteration No: 15 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 64.52706202077027, 'beta': 69.64235997340802}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 30.01 sec. Users per second: 1355
# SearchBayesianSkopt: New best config found. Config 14: {'alpha': 64.52706202077027, 'beta': 69.64235997340802} - results: PRECISION: 0.0496459, PRECISION_RECALL_MIN_DEN: 0.0832935, RECALL: 0.0780865, MAP: 0.0239840, MAP_MIN_DEN: 0.0395439, MRR: 0.1659414, NDCG: 0.0797949, F1: 0.0606999, HIT_RATE: 0.3388826, ARHR_ALL_HITS: 0.1980740, NOVELTY: 0.0043392, AVERAGE_POPULARITY: 0.2001678, DIVERSITY_MEAN_INTER_LIST: 0.9412259, DIVERSITY_HERFINDAHL: 0.9941203, COVERAGE_ITEM: 0.5185457, COVERAGE_ITEM_HIT: 0.0484351, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3310433, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0373635, SHANNON_ENTROPY: 9.1618569, RATIO_DIVERSITY_HERFINDAHL: 0.9944398, RATIO_DIVERSITY_GINI: 0.0724826, RATIO_SHANNON_ENTROPY: 0.6777197, RATIO_AVERAGE_POPULARITY: 3.9222489, RATIO_NOVELTY: 0.2442287,
#
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 30.2422
# Function value obtained: -0.0240
# Current minimum: -0.0240
# Iteration No: 16 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 32.64419215935867, 'beta': 10.074938294565131}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 29.50 sec. Users per second: 1378
# SearchBayesianSkopt: Config 15 is suboptimal. Config: {'alpha': 32.64419215935867, 'beta': 10.074938294565131} - results: PRECISION: 0.0495106, PRECISION_RECALL_MIN_DEN: 0.0829645, RECALL: 0.0777752, MAP: 0.0239441, MAP_MIN_DEN: 0.0394650, MRR: 0.1658043, NDCG: 0.0796219, F1: 0.0605048, HIT_RATE: 0.3383908, ARHR_ALL_HITS: 0.1978580, NOVELTY: 0.0043713, AVERAGE_POPULARITY: 0.1921660, DIVERSITY_MEAN_INTER_LIST: 0.9465369, DIVERSITY_HERFINDAHL: 0.9946514, COVERAGE_ITEM: 0.5307871, COVERAGE_ITEM_HIT: 0.0499041, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3305628, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0397216, SHANNON_ENTROPY: 9.2835126, RATIO_DIVERSITY_HERFINDAHL: 0.9949711, RATIO_DIVERSITY_GINI: 0.0770572, RATIO_SHANNON_ENTROPY: 0.6867188, RATIO_AVERAGE_POPULARITY: 3.7654563, RATIO_NOVELTY: 0.2460316,
#
# Iteration No: 16 ended. Evaluation done at random point.
# Time taken: 29.7394
# Function value obtained: -0.0239
# Current minimum: -0.0240
# Iteration No: 17 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.5131530503433291, 'beta': 77.62137199633872}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 29.30 sec. Users per second: 1388
# SearchBayesianSkopt: Config 16 is suboptimal. Config: {'alpha': 0.5131530503433291, 'beta': 77.62137199633872} - results: PRECISION: 0.0434761, PRECISION_RECALL_MIN_DEN: 0.0746722, RECALL: 0.0703369, MAP: 0.0206921, MAP_MIN_DEN: 0.0349366, MRR: 0.1490186, NDCG: 0.0710091, F1: 0.0537368, HIT_RATE: 0.3098166, ARHR_ALL_HITS: 0.1745841, NOVELTY: 0.0039687, AVERAGE_POPULARITY: 0.3055820, DIVERSITY_MEAN_INTER_LIST: 0.8246961, DIVERSITY_HERFINDAHL: 0.9824676, COVERAGE_ITEM: 0.3258253, COVERAGE_ITEM_HIT: 0.0326437, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3026496, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0136427, SHANNON_ENTROPY: 7.4485006, RATIO_DIVERSITY_HERFINDAHL: 0.9827834, RATIO_DIVERSITY_GINI: 0.0264658, RATIO_SHANNON_ENTROPY: 0.5509795, RATIO_AVERAGE_POPULARITY: 5.9878212, RATIO_NOVELTY: 0.2233741,
#
# Iteration No: 17 ended. Evaluation done at random point.
# Time taken: 29.5024
# Function value obtained: -0.0207
# Current minimum: -0.0240
# Iteration No: 18 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 98.55296477490153, 'beta': 28.598796795799924}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 27.76 sec. Users per second: 1465
# SearchBayesianSkopt: Config 17 is suboptimal. Config: {'alpha': 98.55296477490153, 'beta': 28.598796795799924} - results: PRECISION: 0.0495254, PRECISION_RECALL_MIN_DEN: 0.0829599, RECALL: 0.0777667, MAP: 0.0239459, MAP_MIN_DEN: 0.0394595, MRR: 0.1657661, NDCG: 0.0796143, F1: 0.0605132, HIT_RATE: 0.3383416, ARHR_ALL_HITS: 0.1978333, NOVELTY: 0.0043722, AVERAGE_POPULARITY: 0.1919363, DIVERSITY_MEAN_INTER_LIST: 0.9466874, DIVERSITY_HERFINDAHL: 0.9946664, COVERAGE_ITEM: 0.5311136, COVERAGE_ITEM_HIT: 0.0499041, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3305148, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0397916, SHANNON_ENTROPY: 9.2872006, RATIO_DIVERSITY_HERFINDAHL: 0.9949861, RATIO_DIVERSITY_GINI: 0.0771929, RATIO_SHANNON_ENTROPY: 0.6869916, RATIO_AVERAGE_POPULARITY: 3.7609549, RATIO_NOVELTY: 0.2460856,
#
# Iteration No: 18 ended. Evaluation done at random point.
# Time taken: 27.9688
# Function value obtained: -0.0239
# Current minimum: -0.0240
# Iteration No: 19 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 95.02990169981848, 'beta': 21.226827686269107}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 28.23 sec. Users per second: 1440
# SearchBayesianSkopt: Config 18 is suboptimal. Config: {'alpha': 95.02990169981848, 'beta': 21.226827686269107} - results: PRECISION: 0.0495451, PRECISION_RECALL_MIN_DEN: 0.0829962, RECALL: 0.0778074, MAP: 0.0239419, MAP_MIN_DEN: 0.0394585, MRR: 0.1657637, NDCG: 0.0796234, F1: 0.0605402, HIT_RATE: 0.3385629, ARHR_ALL_HITS: 0.1978169, NOVELTY: 0.0043752, AVERAGE_POPULARITY: 0.1912164, DIVERSITY_MEAN_INTER_LIST: 0.9471457, DIVERSITY_HERFINDAHL: 0.9947122, COVERAGE_ITEM: 0.5321337, COVERAGE_ITEM_HIT: 0.0501489, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3307310, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0400083, SHANNON_ENTROPY: 9.2983938, RATIO_DIVERSITY_HERFINDAHL: 0.9950320, RATIO_DIVERSITY_GINI: 0.0776133, RATIO_SHANNON_ENTROPY: 0.6878196, RATIO_AVERAGE_POPULARITY: 3.7468475, RATIO_NOVELTY: 0.2462538,
#
# Iteration No: 19 ended. Evaluation done at random point.
# Time taken: 28.4483
# Function value obtained: -0.0239
# Current minimum: -0.0240
# Iteration No: 20 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 91.50402438319392, 'beta': 44.94794657046795}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 29.26 sec. Users per second: 1390
# SearchBayesianSkopt: Config 19 is suboptimal. Config: {'alpha': 91.50402438319392, 'beta': 44.94794657046795} - results: PRECISION: 0.0495647, PRECISION_RECALL_MIN_DEN: 0.0830780, RECALL: 0.0778716, MAP: 0.0239703, MAP_MIN_DEN: 0.0395286, MRR: 0.1659103, NDCG: 0.0797106, F1: 0.0605743, HIT_RATE: 0.3382187, ARHR_ALL_HITS: 0.1980178, NOVELTY: 0.0043630, AVERAGE_POPULARITY: 0.1941699, DIVERSITY_MEAN_INTER_LIST: 0.9452351, DIVERSITY_HERFINDAHL: 0.9945212, COVERAGE_ITEM: 0.5274003, COVERAGE_ITEM_HIT: 0.0494961, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3303947, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0390714, SHANNON_ENTROPY: 9.2523746, RATIO_DIVERSITY_HERFINDAHL: 0.9948408, RATIO_DIVERSITY_GINI: 0.0757958, RATIO_SHANNON_ENTROPY: 0.6844155, RATIO_AVERAGE_POPULARITY: 3.8047223, RATIO_NOVELTY: 0.2455686,
#
# Iteration No: 20 ended. Evaluation done at random point.
# Time taken: 29.4707
# Function value obtained: -0.0240
# Current minimum: -0.0240
# Iteration No: 21 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 97.50861816431964, 'beta': 70.44946219517954}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 29.54 sec. Users per second: 1376
# SearchBayesianSkopt: Config 20 is suboptimal. Config: {'alpha': 97.50861816431964, 'beta': 70.44946219517954} - results: PRECISION: 0.0496287, PRECISION_RECALL_MIN_DEN: 0.0832112, RECALL: 0.0779958, MAP: 0.0239823, MAP_MIN_DEN: 0.0395415, MRR: 0.1658969, NDCG: 0.0797629, F1: 0.0606597, HIT_RATE: 0.3386121, ARHR_ALL_HITS: 0.1980574, NOVELTY: 0.0043533, AVERAGE_POPULARITY: 0.1965472, DIVERSITY_MEAN_INTER_LIST: 0.9436765, DIVERSITY_HERFINDAHL: 0.9943653, COVERAGE_ITEM: 0.5238503, COVERAGE_ITEM_HIT: 0.0490064, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3307790, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0383390, SHANNON_ENTROPY: 9.2152605, RATIO_DIVERSITY_HERFINDAHL: 0.9946849, RATIO_DIVERSITY_GINI: 0.0743748, RATIO_SHANNON_ENTROPY: 0.6816701, RATIO_AVERAGE_POPULARITY: 3.8513041, RATIO_NOVELTY: 0.2450207,
#
# Iteration No: 21 ended. Evaluation done at random point.
# Time taken: 29.7807
# Function value obtained: -0.0240
# Current minimum: -0.0240
# Iteration No: 22 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 96.99354473103243, 'beta': 16.948265837649558}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 29.37 sec. Users per second: 1385
# SearchBayesianSkopt: Config 21 is suboptimal. Config: {'alpha': 96.99354473103243, 'beta': 16.948265837649558} - results: PRECISION: 0.0495303, PRECISION_RECALL_MIN_DEN: 0.0829389, RECALL: 0.0777514, MAP: 0.0239385, MAP_MIN_DEN: 0.0394662, MRR: 0.1657013, NDCG: 0.0796021, F1: 0.0605123, HIT_RATE: 0.3383908, ARHR_ALL_HITS: 0.1977571, NOVELTY: 0.0043774, AVERAGE_POPULARITY: 0.1906904, DIVERSITY_MEAN_INTER_LIST: 0.9474752, DIVERSITY_HERFINDAHL: 0.9947452, COVERAGE_ITEM: 0.5330314, COVERAGE_ITEM_HIT: 0.0502305, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3305628, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0401832, SHANNON_ENTROPY: 9.3066224, RATIO_DIVERSITY_HERFINDAHL: 0.9950649, RATIO_DIVERSITY_GINI: 0.0779526, RATIO_SHANNON_ENTROPY: 0.6884283, RATIO_AVERAGE_POPULARITY: 3.7365413, RATIO_NOVELTY: 0.2463766,
#
# Iteration No: 22 ended. Evaluation done at random point.
# Time taken: 29.6066
# Function value obtained: -0.0239
# Current minimum: -0.0240
# Iteration No: 23 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 24.953416746282493, 'beta': 10.947409813070111}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 29.97 sec. Users per second: 1357
# SearchBayesianSkopt: Config 22 is suboptimal. Config: {'alpha': 24.953416746282493, 'beta': 10.947409813070111} - results: PRECISION: 0.0495426, PRECISION_RECALL_MIN_DEN: 0.0830216, RECALL: 0.0778217, MAP: 0.0239586, MAP_MIN_DEN: 0.0395078, MRR: 0.1658907, NDCG: 0.0796789, F1: 0.0605427, HIT_RATE: 0.3382432, ARHR_ALL_HITS: 0.1979642, NOVELTY: 0.0043653, AVERAGE_POPULARITY: 0.1936255, DIVERSITY_MEAN_INTER_LIST: 0.9455913, DIVERSITY_HERFINDAHL: 0.9945568, COVERAGE_ITEM: 0.5283796, COVERAGE_ITEM_HIT: 0.0496185, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3304187, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0392438, SHANNON_ENTROPY: 9.2607829, RATIO_DIVERSITY_HERFINDAHL: 0.9948765, RATIO_DIVERSITY_GINI: 0.0761303, RATIO_SHANNON_ENTROPY: 0.6850375, RATIO_AVERAGE_POPULARITY: 3.7940534, RATIO_NOVELTY: 0.2456943,
#
# Iteration No: 23 ended. Evaluation done at random point.
# Time taken: 30.2041
# Function value obtained: -0.0240
# Current minimum: -0.0240
# Iteration No: 24 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 51.739237433861305, 'beta': 54.83738575895411}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 29.79 sec. Users per second: 1365
# SearchBayesianSkopt: New best config found. Config 23: {'alpha': 51.739237433861305, 'beta': 54.83738575895411} - results: PRECISION: 0.0496459, PRECISION_RECALL_MIN_DEN: 0.0833004, RECALL: 0.0780937, MAP: 0.0239845, MAP_MIN_DEN: 0.0395471, MRR: 0.1659408, NDCG: 0.0797997, F1: 0.0607021, HIT_RATE: 0.3389072, ARHR_ALL_HITS: 0.1980816, NOVELTY: 0.0043399, AVERAGE_POPULARITY: 0.1999981, DIVERSITY_MEAN_INTER_LIST: 0.9413446, DIVERSITY_HERFINDAHL: 0.9941321, COVERAGE_ITEM: 0.5186273, COVERAGE_ITEM_HIT: 0.0484351, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3310673, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0373981, SHANNON_ENTROPY: 9.1642612, RATIO_DIVERSITY_HERFINDAHL: 0.9944517, RATIO_DIVERSITY_GINI: 0.0725496, RATIO_SHANNON_ENTROPY: 0.6778976, RATIO_AVERAGE_POPULARITY: 3.9189238, RATIO_NOVELTY: 0.2442633,
#
# Iteration No: 24 ended. Evaluation done at random point.
# Time taken: 30.0558
# Function value obtained: -0.0240
# Current minimum: -0.0240
# Iteration No: 25 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 55.4709961115278, 'beta': 0.2526354137588727}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 29.55 sec. Users per second: 1376
# SearchBayesianSkopt: Config 24 is suboptimal. Config: {'alpha': 55.4709961115278, 'beta': 0.2526354137588727} - results: PRECISION: 0.0494418, PRECISION_RECALL_MIN_DEN: 0.0828032, RECALL: 0.0776285, MAP: 0.0239241, MAP_MIN_DEN: 0.0394464, MRR: 0.1658473, NDCG: 0.0795458, F1: 0.0604090, HIT_RATE: 0.3381695, ARHR_ALL_HITS: 0.1977961, NOVELTY: 0.0043853, AVERAGE_POPULARITY: 0.1887819, DIVERSITY_MEAN_INTER_LIST: 0.9486530, DIVERSITY_HERFINDAHL: 0.9948630, COVERAGE_ITEM: 0.5355205, COVERAGE_ITEM_HIT: 0.0505978, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3303466, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0407578, SHANNON_ENTROPY: 9.3358005, RATIO_DIVERSITY_HERFINDAHL: 0.9951827, RATIO_DIVERSITY_GINI: 0.0790672, RATIO_SHANNON_ENTROPY: 0.6905866, RATIO_AVERAGE_POPULARITY: 3.6991441, RATIO_NOVELTY: 0.2468236,
#
# Iteration No: 25 ended. Evaluation done at random point.
# Time taken: 29.7724
# Function value obtained: -0.0239
# Current minimum: -0.0240
# Iteration No: 26 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 28.22861597877992, 'beta': 1.6924507765316181}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 29.09 sec. Users per second: 1398
# SearchBayesianSkopt: Config 25 is suboptimal. Config: {'alpha': 28.22861597877992, 'beta': 1.6924507765316181} - results: PRECISION: 0.0494984, PRECISION_RECALL_MIN_DEN: 0.0828927, RECALL: 0.0777091, MAP: 0.0239342, MAP_MIN_DEN: 0.0394520, MRR: 0.1657801, NDCG: 0.0795785, F1: 0.0604756, HIT_RATE: 0.3383908, ARHR_ALL_HITS: 0.1977933, NOVELTY: 0.0043828, AVERAGE_POPULARITY: 0.1893894, DIVERSITY_MEAN_INTER_LIST: 0.9482804, DIVERSITY_HERFINDAHL: 0.9948257, COVERAGE_ITEM: 0.5345820, COVERAGE_ITEM_HIT: 0.0504754, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3305628, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0405694, SHANNON_ENTROPY: 9.3265785, RATIO_DIVERSITY_HERFINDAHL: 0.9951455, RATIO_DIVERSITY_GINI: 0.0787018, RATIO_SHANNON_ENTROPY: 0.6899045, RATIO_AVERAGE_POPULARITY: 3.7110488, RATIO_NOVELTY: 0.2466821,
#
# Iteration No: 26 ended. Evaluation done at random point.
# Time taken: 29.3208
# Function value obtained: -0.0239
# Current minimum: -0.0240
# Iteration No: 27 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 31.04944214942656, 'beta': 2.1164283997817117}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 28.91 sec. Users per second: 1407
# SearchBayesianSkopt: Config 26 is suboptimal. Config: {'alpha': 31.04944214942656, 'beta': 2.1164283997817117} - results: PRECISION: 0.0494984, PRECISION_RECALL_MIN_DEN: 0.0828940, RECALL: 0.0777137, MAP: 0.0239354, MAP_MIN_DEN: 0.0394483, MRR: 0.1657778, NDCG: 0.0795760, F1: 0.0604770, HIT_RATE: 0.3383416, ARHR_ALL_HITS: 0.1977955, NOVELTY: 0.0043825, AVERAGE_POPULARITY: 0.1894731, DIVERSITY_MEAN_INTER_LIST: 0.9482278, DIVERSITY_HERFINDAHL: 0.9948204, COVERAGE_ITEM: 0.5343779, COVERAGE_ITEM_HIT: 0.0504754, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3305148, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0405383, SHANNON_ENTROPY: 9.3251674, RATIO_DIVERSITY_HERFINDAHL: 0.9951402, RATIO_DIVERSITY_GINI: 0.0786415, RATIO_SHANNON_ENTROPY: 0.6898001, RATIO_AVERAGE_POPULARITY: 3.7126881, RATIO_NOVELTY: 0.2466613,
#
# Iteration No: 27 ended. Evaluation done at random point.
# Time taken: 29.1621
# Function value obtained: -0.0239
# Current minimum: -0.0240
# Iteration No: 28 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 84.28219764271167, 'beta': 39.964923866648604}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 29.78 sec. Users per second: 1366
# SearchBayesianSkopt: Config 27 is suboptimal. Config: {'alpha': 84.28219764271167, 'beta': 39.964923866648604} - results: PRECISION: 0.0495475, PRECISION_RECALL_MIN_DEN: 0.0830489, RECALL: 0.0778429, MAP: 0.0239627, MAP_MIN_DEN: 0.0395198, MRR: 0.1658529, NDCG: 0.0796890, F1: 0.0605528, HIT_RATE: 0.3381203, ARHR_ALL_HITS: 0.1979558, NOVELTY: 0.0043638, AVERAGE_POPULARITY: 0.1939843, DIVERSITY_MEAN_INTER_LIST: 0.9453566, DIVERSITY_HERFINDAHL: 0.9945333, COVERAGE_ITEM: 0.5278492, COVERAGE_ITEM_HIT: 0.0495369, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3302986, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0391389, SHANNON_ENTROPY: 9.2553418, RATIO_DIVERSITY_HERFINDAHL: 0.9948530, RATIO_DIVERSITY_GINI: 0.0759268, RATIO_SHANNON_ENTROPY: 0.6846350, RATIO_AVERAGE_POPULARITY: 3.8010851, RATIO_NOVELTY: 0.2456130,
#
# Iteration No: 28 ended. Evaluation done at random point.
# Time taken: 29.9837
# Function value obtained: -0.0240
# Current minimum: -0.0240
# Iteration No: 29 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 40.357523895654026, 'beta': 52.97581093173702}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 28.31 sec. Users per second: 1436
# SearchBayesianSkopt: Config 28 is suboptimal. Config: {'alpha': 40.357523895654026, 'beta': 52.97581093173702} - results: PRECISION: 0.0495770, PRECISION_RECALL_MIN_DEN: 0.0831400, RECALL: 0.0779468, MAP: 0.0239776, MAP_MIN_DEN: 0.0395395, MRR: 0.1661169, NDCG: 0.0797708, F1: 0.0606063, HIT_RATE: 0.3389072, ARHR_ALL_HITS: 0.1981891, NOVELTY: 0.0043304, AVERAGE_POPULARITY: 0.2024353, DIVERSITY_MEAN_INTER_LIST: 0.9396367, DIVERSITY_HERFINDAHL: 0.9939614, COVERAGE_ITEM: 0.5148733, COVERAGE_ITEM_HIT: 0.0482719, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3310673, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0367272, SHANNON_ENTROPY: 9.1276079, RATIO_DIVERSITY_HERFINDAHL: 0.9942808, RATIO_DIVERSITY_GINI: 0.0712481, RATIO_SHANNON_ENTROPY: 0.6751862, RATIO_AVERAGE_POPULARITY: 3.9666808, RATIO_NOVELTY: 0.2437298,
#
# Iteration No: 29 ended. Evaluation done at random point.
# Time taken: 28.5279
# Function value obtained: -0.0240
# Current minimum: -0.0240
# Iteration No: 30 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 48.042126136428834, 'beta': 34.586372961473806}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 28.16 sec. Users per second: 1444
# SearchBayesianSkopt: Config 29 is suboptimal. Config: {'alpha': 48.042126136428834, 'beta': 34.586372961473806} - results: PRECISION: 0.0496287, PRECISION_RECALL_MIN_DEN: 0.0832211, RECALL: 0.0780064, MAP: 0.0239811, MAP_MIN_DEN: 0.0395412, MRR: 0.1658901, NDCG: 0.0797643, F1: 0.0606629, HIT_RATE: 0.3386367, ARHR_ALL_HITS: 0.1980493, NOVELTY: 0.0043534, AVERAGE_POPULARITY: 0.1965197, DIVERSITY_MEAN_INTER_LIST: 0.9436959, DIVERSITY_HERFINDAHL: 0.9943673, COVERAGE_ITEM: 0.5239319, COVERAGE_ITEM_HIT: 0.0490064, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3308030, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0383500, SHANNON_ENTROPY: 9.2157009, RATIO_DIVERSITY_HERFINDAHL: 0.9946869, RATIO_DIVERSITY_GINI: 0.0743963, RATIO_SHANNON_ENTROPY: 0.6817026, RATIO_AVERAGE_POPULARITY: 3.8507646, RATIO_NOVELTY: 0.2450268,
#
# Iteration No: 30 ended. Evaluation done at random point.
# Time taken: 28.3715
# Function value obtained: -0.0240
# Current minimum: -0.0240
# Iteration No: 31 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 86.85165434288926, 'beta': 0.967995113507625}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 27.93 sec. Users per second: 1456
# SearchBayesianSkopt: Config 30 is suboptimal. Config: {'alpha': 86.85165434288926, 'beta': 0.967995113507625} - results: PRECISION: 0.0494393, PRECISION_RECALL_MIN_DEN: 0.0827989, RECALL: 0.0776261, MAP: 0.0239255, MAP_MIN_DEN: 0.0394500, MRR: 0.1658511, NDCG: 0.0795480, F1: 0.0604064, HIT_RATE: 0.3381449, ARHR_ALL_HITS: 0.1978071, NOVELTY: 0.0043850, AVERAGE_POPULARITY: 0.1888546, DIVERSITY_MEAN_INTER_LIST: 0.9486096, DIVERSITY_HERFINDAHL: 0.9948586, COVERAGE_ITEM: 0.5354797, COVERAGE_ITEM_HIT: 0.0505570, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3303226, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0407376, SHANNON_ENTROPY: 9.3346867, RATIO_DIVERSITY_HERFINDAHL: 0.9951784, RATIO_DIVERSITY_GINI: 0.0790280, RATIO_SHANNON_ENTROPY: 0.6905043, RATIO_AVERAGE_POPULARITY: 3.7005686, RATIO_NOVELTY: 0.2468065,
#
# Iteration No: 31 ended. Evaluation done at random point.
# Time taken: 28.1476
# Function value obtained: -0.0239
# Current minimum: -0.0240
# Iteration No: 32 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 26.192769121489405, 'beta': 16.771522231341198}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 28.18 sec. Users per second: 1443
# SearchBayesianSkopt: New best config found. Config 31: {'alpha': 26.192769121489405, 'beta': 16.771522231341198} - results: PRECISION: 0.0495721, PRECISION_RECALL_MIN_DEN: 0.0831275, RECALL: 0.0779155, MAP: 0.0239859, MAP_MIN_DEN: 0.0395527, MRR: 0.1659938, NDCG: 0.0797483, F1: 0.0605931, HIT_RATE: 0.3382924, ARHR_ALL_HITS: 0.1981295, NOVELTY: 0.0043568, AVERAGE_POPULARITY: 0.1956830, DIVERSITY_MEAN_INTER_LIST: 0.9442476, DIVERSITY_HERFINDAHL: 0.9944224, COVERAGE_ITEM: 0.5251561, COVERAGE_ITEM_HIT: 0.0490880, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3304667, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0386075, SHANNON_ENTROPY: 9.2285754, RATIO_DIVERSITY_HERFINDAHL: 0.9947421, RATIO_DIVERSITY_GINI: 0.0748958, RATIO_SHANNON_ENTROPY: 0.6826550, RATIO_AVERAGE_POPULARITY: 3.8343708, RATIO_NOVELTY: 0.2452182,
#
# Iteration No: 32 ended. Evaluation done at random point.
# Time taken: 28.4191
# Function value obtained: -0.0240
# Current minimum: -0.0240
# Iteration No: 33 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 19.472683348920032, 'beta': 84.21385588827171}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 28.73 sec. Users per second: 1416
# SearchBayesianSkopt: Config 32 is suboptimal. Config: {'alpha': 19.472683348920032, 'beta': 84.21385588827171} - results: PRECISION: 0.0489795, PRECISION_RECALL_MIN_DEN: 0.0826712, RECALL: 0.0776225, MAP: 0.0237740, MAP_MIN_DEN: 0.0394453, MRR: 0.1655687, NDCG: 0.0793843, F1: 0.0600608, HIT_RATE: 0.3363006, ARHR_ALL_HITS: 0.1970043, NOVELTY: 0.0042471, AVERAGE_POPULARITY: 0.2246718, DIVERSITY_MEAN_INTER_LIST: 0.9221434, DIVERSITY_HERFINDAHL: 0.9922121, COVERAGE_ITEM: 0.4814951, COVERAGE_ITEM_HIT: 0.0442323, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3285210, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0311030, SHANNON_ENTROPY: 8.7919193, RATIO_DIVERSITY_HERFINDAHL: 0.9925310, RATIO_DIVERSITY_GINI: 0.0603376, RATIO_SHANNON_ENTROPY: 0.6503547, RATIO_AVERAGE_POPULARITY: 4.4023996, RATIO_NOVELTY: 0.2390431,
#
# Iteration No: 33 ended. Evaluation done at random point.
# Time taken: 28.9480
# Function value obtained: -0.0238
# Current minimum: -0.0240
# Iteration No: 34 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 26.1394999664828, 'beta': 97.18453334494617}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 29.06 sec. Users per second: 1399
# SearchBayesianSkopt: Config 33 is suboptimal. Config: {'alpha': 26.1394999664828, 'beta': 97.18453334494617} - results: PRECISION: 0.0491049, PRECISION_RECALL_MIN_DEN: 0.0828190, RECALL: 0.0777465, MAP: 0.0238054, MAP_MIN_DEN: 0.0394386, MRR: 0.1656674, NDCG: 0.0794565, F1: 0.0601922, HIT_RATE: 0.3369891, ARHR_ALL_HITS: 0.1971978, NOVELTY: 0.0042608, AVERAGE_POPULARITY: 0.2208947, DIVERSITY_MEAN_INTER_LIST: 0.9253935, DIVERSITY_HERFINDAHL: 0.9925371, COVERAGE_ITEM: 0.4867589, COVERAGE_ITEM_HIT: 0.0448443, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3291936, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0319707, SHANNON_ENTROPY: 8.8489120, RATIO_DIVERSITY_HERFINDAHL: 0.9928561, RATIO_DIVERSITY_GINI: 0.0620209, RATIO_SHANNON_ENTROPY: 0.6545706, RATIO_AVERAGE_POPULARITY: 4.3283897, RATIO_NOVELTY: 0.2398136,
#
# Iteration No: 34 ended. Evaluation done at random point.
# Time taken: 29.2901
# Function value obtained: -0.0238
# Current minimum: -0.0240
# Iteration No: 35 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 71.20895650161368, 'beta': 17.207705509883144}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 28.20 sec. Users per second: 1442
# SearchBayesianSkopt: Config 34 is suboptimal. Config: {'alpha': 71.20895650161368, 'beta': 17.207705509883144} - results: PRECISION: 0.0495180, PRECISION_RECALL_MIN_DEN: 0.0829549, RECALL: 0.0777695, MAP: 0.0239431, MAP_MIN_DEN: 0.0394514, MRR: 0.1658031, NDCG: 0.0796090, F1: 0.0605086, HIT_RATE: 0.3384154, ARHR_ALL_HITS: 0.1978479, NOVELTY: 0.0043744, AVERAGE_POPULARITY: 0.1914115, DIVERSITY_MEAN_INTER_LIST: 0.9470226, DIVERSITY_HERFINDAHL: 0.9946999, COVERAGE_ITEM: 0.5319297, COVERAGE_ITEM_HIT: 0.0501081, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3305869, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0399593, SHANNON_ENTROPY: 9.2955191, RATIO_DIVERSITY_HERFINDAHL: 0.9950196, RATIO_DIVERSITY_GINI: 0.0775182, RATIO_SHANNON_ENTROPY: 0.6876069, RATIO_AVERAGE_POPULARITY: 3.7506708, RATIO_NOVELTY: 0.2462093,
#
# Iteration No: 35 ended. Evaluation done at random point.
# Time taken: 28.4148
# Function value obtained: -0.0239
# Current minimum: -0.0240
# Iteration No: 36 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 16.665423497533318, 'beta': 93.38807413637696}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 28.21 sec. Users per second: 1442
# SearchBayesianSkopt: Config 35 is suboptimal. Config: {'alpha': 16.665423497533318, 'beta': 93.38807413637696} - results: PRECISION: 0.0488049, PRECISION_RECALL_MIN_DEN: 0.0825995, RECALL: 0.0775950, MAP: 0.0236091, MAP_MIN_DEN: 0.0392483, MRR: 0.1646821, NDCG: 0.0790744, F1: 0.0599212, HIT_RATE: 0.3355383, ARHR_ALL_HITS: 0.1958049, NOVELTY: 0.0042222, AVERAGE_POPULARITY: 0.2314947, DIVERSITY_MEAN_INTER_LIST: 0.9160471, DIVERSITY_HERFINDAHL: 0.9916025, COVERAGE_ITEM: 0.4714571, COVERAGE_ITEM_HIT: 0.0435794, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3277763, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0294988, SHANNON_ENTROPY: 8.6862099, RATIO_DIVERSITY_HERFINDAHL: 0.9919212, RATIO_DIVERSITY_GINI: 0.0572256, RATIO_SHANNON_ENTROPY: 0.6425352, RATIO_AVERAGE_POPULARITY: 4.5360947, RATIO_NOVELTY: 0.2376426,
#
# Iteration No: 36 ended. Evaluation done at random point.
# Time taken: 28.4274
# Function value obtained: -0.0236
# Current minimum: -0.0240
# Iteration No: 37 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 79.6131479555512, 'beta': 79.16320148236152}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 28.14 sec. Users per second: 1445
# SearchBayesianSkopt: New best config found. Config 36: {'alpha': 79.6131479555512, 'beta': 79.16320148236152} - results: PRECISION: 0.0496607, PRECISION_RECALL_MIN_DEN: 0.0833140, RECALL: 0.0781043, MAP: 0.0239933, MAP_MIN_DEN: 0.0395512, MRR: 0.1659078, NDCG: 0.0798065, F1: 0.0607163, HIT_RATE: 0.3388088, ARHR_ALL_HITS: 0.1981005, NOVELTY: 0.0043424, AVERAGE_POPULARITY: 0.1993136, DIVERSITY_MEAN_INTER_LIST: 0.9418085, DIVERSITY_HERFINDAHL: 0.9941785, COVERAGE_ITEM: 0.5191986, COVERAGE_ITEM_HIT: 0.0485576, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3309712, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0375485, SHANNON_ENTROPY: 9.1740228, RATIO_DIVERSITY_HERFINDAHL: 0.9944981, RATIO_DIVERSITY_GINI: 0.0728415, RATIO_SHANNON_ENTROPY: 0.6786196, RATIO_AVERAGE_POPULARITY: 3.9055121, RATIO_NOVELTY: 0.2444095,
#
# Iteration No: 37 ended. Evaluation done at random point.
# Time taken: 28.3586
# Function value obtained: -0.0240
# Current minimum: -0.0240
# Iteration No: 38 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 13.818106309673642, 'beta': 33.70603022026565}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 28.06 sec. Users per second: 1449
# SearchBayesianSkopt: Config 37 is suboptimal. Config: {'alpha': 13.818106309673642, 'beta': 33.70603022026565} - results: PRECISION: 0.0493729, PRECISION_RECALL_MIN_DEN: 0.0830257, RECALL: 0.0778928, MAP: 0.0238991, MAP_MIN_DEN: 0.0394935, MRR: 0.1658511, NDCG: 0.0796293, F1: 0.0604373, HIT_RATE: 0.3381449, ARHR_ALL_HITS: 0.1976899, NOVELTY: 0.0042941, AVERAGE_POPULARITY: 0.2119281, DIVERSITY_MEAN_INTER_LIST: 0.9326133, DIVERSITY_HERFINDAHL: 0.9932590, COVERAGE_ITEM: 0.5010813, COVERAGE_ITEM_HIT: 0.0464357, ITEMS_IN_GT: 0.9929816, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3303226, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0342564, SHANNON_ENTROPY: 8.9851212, RATIO_DIVERSITY_HERFINDAHL: 0.9935783, RATIO_DIVERSITY_GINI: 0.0664550, RATIO_SHANNON_ENTROPY: 0.6646462, RATIO_AVERAGE_POPULARITY: 4.1526903, RATIO_NOVELTY: 0.2416891,
#
# Iteration No: 38 ended. Evaluation done at random point.
# Time taken: 28.2754
# Function value obtained: -0.0239
# Current minimum: -0.0240
# Iteration No: 39 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 52.83924111404173, 'beta': 89.06154929900613}
# DifferentLossScoresHybridRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [49], in <cell line: 1>()
# ----> 1 hyperparameterSearch.search(recommender_input_args = recommender_input_args,
#       2                             hyperparameter_search_space = hyperparameters_range_dictionary_hybrid,
#       3                             n_cases = n_cases,
#       4                             n_random_starts = n_random_starts,
#       5                             save_model = "no",
#       6                             output_folder_path = output_folder_path, # Where to save the results
#       7                             output_file_name_root = recommender_class.RECOMMENDER_NAME, # How to call the files
#       8                             metric_to_optimize = metric_to_optimize,
#       9                             cutoff_to_optimize = cutoff_to_optimize,
#      10                             )
#
# File ~\AppData\Roaming\JetBrains\DataSpell2022.2\projects\RecSys2022\HyperparameterTuning\SearchBayesianSkopt.py:340, in SearchBayesianSkopt.search(self, recommender_input_args, hyperparameter_search_space, metric_to_optimize, cutoff_to_optimize, n_cases, n_random_starts, output_folder_path, output_file_name_root, save_model, save_metadata, resume_from_saved, recommender_input_args_last_test, evaluate_on_test, max_total_time, terminate_on_memory_error)
#     333         self.n_loaded_counter = self.model_counter
#     336     if self.n_calls - self.model_counter > 0:
#     337         # When resuming an incomplete search the gp_minimize will continue to tell you "Evaluating function at random point" instead
#     338         # of "Searching for the next optimal point". This may be due to a bug in the print rather than the underlying process
#     339         # https://github.com/scikit-optimize/scikit-optimize/issues/949
# --> 340         self.result = gp_minimize(self._objective_function_list_input,
#     341                                   self.hyperparams_values,
#     342                                   base_estimator=None,
#     343                                   n_calls=max(0, self.n_calls - self.model_counter),
#     344                                   n_initial_points= max(0, self.n_random_starts - self.model_counter),
#     345                                   initial_point_generator = "random",
#     346                                   acq_func=self.acq_func,
#     347                                   acq_optimizer=self.acq_optimizer,
#     348                                   x0=self.x0,
#     349                                   y0=self.y0,
#     350                                   random_state=self.random_state,
#     351                                   verbose=self.verbose,
#     352                                   callback=None,
#     353                                   n_points=self.n_point,
#     354                                   n_restarts_optimizer=self.n_restarts_optimizer,
#     355                                   xi=self.xi,
#     356                                   kappa=self.kappa,
#     357                                   noise=self.noise,
#     358                                   n_jobs=self.n_jobs)
#     360 except ValueError as e:
#     361     traceback.print_exc()
#
# File ~\anaconda3\lib\site-packages\skopt\optimizer\gp.py:259, in gp_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, noise, n_jobs, model_queue_size)
#     254 if base_estimator is None:
#     255     base_estimator = cook_estimator(
#     256         "GP", space=space, random_state=rng.randint(0, np.iinfo(np.int32).max),
#     257         noise=noise)
# --> 259 return base_minimize(
#     260     func, space, base_estimator=base_estimator,
#     261     acq_func=acq_func,
#     262     xi=xi, kappa=kappa, acq_optimizer=acq_optimizer, n_calls=n_calls,
#     263     n_points=n_points, n_random_starts=n_random_starts,
#     264     n_initial_points=n_initial_points,
#     265     initial_point_generator=initial_point_generator,
#     266     n_restarts_optimizer=n_restarts_optimizer,
#     267     x0=x0, y0=y0, random_state=rng, verbose=verbose,
#     268     callback=callback, n_jobs=n_jobs, model_queue_size=model_queue_size)
#
# File ~\anaconda3\lib\site-packages\skopt\optimizer\base.py:299, in base_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, n_jobs, model_queue_size)
#     297 for n in range(n_calls):
#     298     next_x = optimizer.ask()
# --> 299     next_y = func(next_x)
#     300     result = optimizer.tell(next_x, next_y)
#     301     result.specs = specs
#
# File ~\AppData\Roaming\JetBrains\DataSpell2022.2\projects\RecSys2022\HyperparameterTuning\SearchBayesianSkopt.py:415, in SearchBayesianSkopt._objective_function_list_input(self, current_fit_hyperparameters_list_of_values)
#     411         raise TimeoutError(self.max_total_time, total_current_time + estimated_last_time)
#     414 current_fit_hyperparameters_dict = dict(zip(self.hyperparams_names, current_fit_hyperparameters_list_of_values))
# --> 415 result = self._objective_function(current_fit_hyperparameters_dict)
#     417 # The search can only progress if there is at least a valid config in the initial random start
#     418 if self.metadata_dict['result_on_validation_df'] is None and self.model_counter >= self.n_random_starts:
#
# File ~\AppData\Roaming\JetBrains\DataSpell2022.2\projects\RecSys2022\HyperparameterTuning\SearchAbstractClass.py:539, in SearchAbstractClass._objective_function(self, current_fit_hyperparameters_dict)
#     534             recommender_instance.save_model(self.output_folder_path, file_name =self.output_file_name_root + "_best_model")
#     537 except (KeyboardInterrupt, SystemExit) as e:
#     538     # If getting a interrupt, terminate without saving the exception
# --> 539     raise e
#     541 # Catch exception only if terminate_on_memory_error is True
#     542 except MEMORY_ERROR_EXCEPTION_TUPLE if self.terminate_on_memory_error else (NeverMatch) as e:
#
# File ~\AppData\Roaming\JetBrains\DataSpell2022.2\projects\RecSys2022\HyperparameterTuning\SearchAbstractClass.py:468, in SearchAbstractClass._objective_function(self, current_fit_hyperparameters_dict)
#     465 self._print("{}: Testing config: {}".format(self.ALGORITHM_NAME, current_fit_hyperparameters_dict))
#     467 was_already_evaluated_flag, was_already_evaluated_index = self._was_already_evaluated_check(current_fit_hyperparameters_dict)
# --> 468 result_df, recommender_instance = self._evaluate_on_validation(current_fit_hyperparameters_dict, was_already_evaluated_flag, was_already_evaluated_index)
#     470 result_series = result_df.loc[self.metadata_dict["cutoff_to_optimize"]]
#     471 current_result = - result_series[self.metric_to_optimize]
#
# File ~\AppData\Roaming\JetBrains\DataSpell2022.2\projects\RecSys2022\HyperparameterTuning\SearchAbstractClass.py:330, in SearchAbstractClass._evaluate_on_validation(self, current_fit_hyperparameters, was_already_evaluated_flag, was_already_evaluated_index)
#     327 start_time = time.time()
#     329 # Evaluate recommender and get results for the first cutoff
# --> 330 result_df, _ = self.evaluator_validation.evaluateRecommender(recommender_instance)
#     332 evaluation_time = time.time() - start_time
#     334 # If the recommender uses Earlystopping, get the selected number of epochs instead of the maximum
#
# File ~\AppData\Roaming\JetBrains\DataSpell2022.2\projects\RecSys2022\Evaluation\Evaluator.py:277, in Evaluator.evaluateRecommender(self, recommender_object)
#     274 self._start_time_print = time.time()
#     275 self._n_users_evaluated = 0
# --> 277 results_dict = self._run_evaluation_on_selected_users(recommender_object, self.users_to_evaluate)
#     280 if self._n_users_evaluated > 0:
#     282     for cutoff in self.cutoff_list:
#
# File ~\AppData\Roaming\JetBrains\DataSpell2022.2\projects\RecSys2022\Evaluation\Evaluator.py:477, in EvaluatorHoldout._run_evaluation_on_selected_users(self, recommender_object, users_to_evaluate, block_size)
#     474     user_batch_start = user_batch_end
#     476     # Compute predictions for a batch of users using vectorization, much more efficient than computing it one at a time
# --> 477     recommended_items_batch_list, scores_batch = recommender_object.recommend(test_user_batch_array,
#     478                                                                               remove_seen_flag=self.exclude_seen,
#     479                                                                               cutoff = self.max_cutoff,
#     480                                                                               remove_top_pop_flag=False,
#     481                                                                               remove_custom_items_flag=self.ignore_items_flag,
#     482                                                                               return_scores = True
#     483                                                                               )
#     485     results_dict = self._compute_metrics_on_recommendation_list(test_user_batch_array = test_user_batch_array,
#     486                                                                 recommended_items_batch_list = recommended_items_batch_list,
#     487                                                                 scores_batch = scores_batch,
#     488                                                                 results_dict = results_dict)
#     491 return results_dict
#
# File ~\AppData\Roaming\JetBrains\DataSpell2022.2\projects\RecSys2022\Recommenders\BaseRecommender.py:147, in BaseRecommender.recommend(self, user_id_array, cutoff, remove_seen_flag, items_to_compute, remove_top_pop_flag, remove_custom_items_flag, return_scores)
#     143 cutoff = min(cutoff, self.URM_train.shape[1] - 1)
#     145 # Compute the scores using the model-specific function
#     146 # Vectorize over all users in user_id_array
# --> 147 scores_batch = self._compute_item_score(user_id_array, items_to_compute=items_to_compute)
#     150 for user_index in range(len(user_id_array)):
#     152     user_id = user_id_array[user_index]
#
# Input In [40], in DifferentLossScoresHybridRecommender2._compute_item_score(self, user_id_array, items_to_compute)
#      26 def _compute_item_score(self, user_id_array, items_to_compute = None):
#      27     item_weights_1 = self.recommender_1._compute_item_score(user_id_array)
# ---> 28     item_weights_2 = self.recommender_2._compute_item_score(user_id_array)
#      30     item_weights = item_weights_1 * self.alpha + item_weights_2 * self.beta
#      32     return item_weights
#
# File ~\AppData\Roaming\JetBrains\DataSpell2022.2\projects\RecSys2022\Recommenders\BaseSimilarityMatrixRecommender.py:95, in BaseItemSimilarityMatrixRecommender._compute_item_score(self, user_id_array, items_to_compute)
#      93     item_scores[:, items_to_compute] = item_scores_all[:, items_to_compute]
#      94 else:
# ---> 95     item_scores = user_profile_array.dot(self.W_sparse).toarray()
#      96 return item_scores
#
# File ~\anaconda3\lib\site-packages\scipy\sparse\base.py:359, in spmatrix.dot(self, other)
#     346 def dot(self, other):
#     347     """Ordinary dot product
#     348
#     349     Examples
#    (...)
#     357
#     358     """
# --> 359     return self * other
#
# File ~\anaconda3\lib\site-packages\scipy\sparse\base.py:480, in spmatrix.__mul__(self, other)
#     478     if self.shape[1] != other.shape[0]:
#     479         raise ValueError('dimension mismatch')
# --> 480     return self._mul_sparse_matrix(other)
#     482 # If it's a list or whatever, treat it like a matrix
#     483 other_a = np.asanyarray(other)
#
# File ~\anaconda3\lib\site-packages\scipy\sparse\compressed.py:522, in _cs_matrix._mul_sparse_matrix(self, other)
#     519 data = np.empty(nnz, dtype=upcast(self.dtype, other.dtype))
#     521 fn = getattr(_sparsetools, self.format + '_matmat')
# --> 522 fn(M, N, np.asarray(self.indptr, dtype=idx_dtype),
#     523    np.asarray(self.indices, dtype=idx_dtype),
#     524    self.data,
#     525    np.asarray(other.indptr, dtype=idx_dtype),
#     526    np.asarray(other.indices, dtype=idx_dtype),
#     527    other.data,
#     528    indptr, indices, data)
#     530 return self.__class__((data, indices, indptr), shape=(M, N))
#
# KeyboardInterrupt:

# %%
from Recommenders.DataIO import DataIO

#explore the results of the search
data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(recommender_class.RECOMMENDER_NAME + "_metadata.zip")

search_metadata.keys()
# Out:
# {'algorithm_name_recommender': 'DifferentLossScoresHybridRecommender'}
# {'algorithm_name_recommender': 'DifferentLossScoresHybridRecommender', 'algorithm_name_search': 'SearchBayesianSkopt'}
# {'algorithm_name_recommender': 'DifferentLossScoresHybridRecommender', 'algorithm_name_search': 'SearchBayesianSkopt', 'cutoff_to_optimize': 10}
# {'algorithm_name_recommender': 'DifferentLossScoresHybridRecommender', 'algorithm_name_search': 'SearchBayesianSkopt', 'cutoff_to_optimize': 10, 'exception_list': [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]}
# {'algorithm_name_recommender': 'DifferentLossScoresHybridRecommender', 'algorithm_name_search': 'SearchBayesianSkopt', 'cutoff_to_optimize': 10, 'exception_list': [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], 'hyperparameters_best': {'alpha': 79.6131479555512, 'beta': 79.16320148236152}}
# {'algorithm_name_recommender': 'DifferentLossScoresHybridRecommender', 'algorithm_name_search': 'SearchBayesianSkopt', 'cutoff_to_optimize': 10, 'exception_list': [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], 'hyperparameters_best': {'alpha': 79.6131479555512, 'beta': 79.16320148236152}, 'hyperparameters_best_index': 36}
# {'algorithm_name_recommender': 'DifferentLossScoresHybridRecommender', 'algorithm_name_search': 'SearchBayesianSkopt', 'cutoff_to_optimize': 10, 'exception_list': [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], 'hyperparameters_best': {'alpha': 79.6131479555512, 'beta': 79.16320148236152}, 'hyperparameters_best_index': 36, 'hyperparameters_df':          alpha       beta
# 0    23.438255  91.966244
# 1    76.723259  39.303201
# 2     47.35665  28.534819
# 3    65.747992   32.83755
# 4    60.107579   30.67584
# ..         ...        ...
# 495        NaN        NaN
# 496        NaN        NaN
# 497        NaN        NaN
# 498        NaN        NaN
# 499        NaN        NaN
#
# [500 rows x 2 columns]}
# {'algorithm_name_recommender': 'DifferentLossScoresHybridRecommender', 'algorithm_name_search': 'SearchBayesianSkopt', 'cutoff_to_optimize': 10, 'exception_list': [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], 'hyperparameters_best': {'alpha': 79.6131479555512, 'beta': 79.16320148236152}, 'hyperparameters_best_index': 36, 'hyperparameters_df':          alpha       beta
# 0    23.438255  91.966244
# 1    76.723259  39.303201
# 2     47.35665  28.534819
# 3    65.747992   32.83755
# 4    60.107579   30.67584
# ..         ...        ...
# 495        NaN        NaN
# 496        NaN        NaN
# 497        NaN        NaN
# 498        NaN        NaN
# 499        NaN        NaN
#
# [500 rows x 2 columns], 'metric_to_optimize': 'MAP'}
# {'algorithm_name_recommender': 'DifferentLossScoresHybridRecommender', 'algorithm_name_search': 'SearchBayesianSkopt', 'cutoff_to_optimize': 10, 'exception_list': [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], 'hyperparameters_best': {'alpha': 79.6131479555512, 'beta': 79.16320148236152}, 'hyperparameters_best_index': 36, 'hyperparameters_df':          alpha       beta
# 0    23.438255  91.966244
# 1    76.723259  39.303201
# 2     47.35665  28.534819
# 3    65.747992   32.83755
# 4    60.107579   30.67584
# ..         ...        ...
# 495        NaN        NaN
# 496        NaN        NaN
# 497        NaN        NaN
# 498        NaN        NaN
# 499        NaN        NaN
#
# [500 rows x 2 columns], 'metric_to_optimize': 'MAP', 'result_on_earlystopping_df': None}
# {'algorithm_name_recommender': 'DifferentLossScoresHybridRecommender', 'algorithm_name_search': 'SearchBayesianSkopt', 'cutoff_to_optimize': 10, 'exception_list': [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], 'hyperparameters_best': {'alpha': 79.6131479555512, 'beta': 79.16320148236152}, 'hyperparameters_best_index': 36, 'hyperparameters_df':          alpha       beta
# 0    23.438255  91.966244
# 1    76.723259  39.303201
# 2     47.35665  28.534819
# 3    65.747992   32.83755
# 4    60.107579   30.67584
# ..         ...        ...
# 495        NaN        NaN
# 496        NaN        NaN
# 497        NaN        NaN
# 498        NaN        NaN
# 499        NaN        NaN
#
# [500 rows x 2 columns], 'metric_to_optimize': 'MAP', 'result_on_earlystopping_df': None, 'result_on_last': None}
# {'algorithm_name_recommender': 'DifferentLossScoresHybridRecommender', 'algorithm_name_search': 'SearchBayesianSkopt', 'cutoff_to_optimize': 10, 'exception_list': [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], 'hyperparameters_best': {'alpha': 79.6131479555512, 'beta': 79.16320148236152}, 'hyperparameters_best_index': 36, 'hyperparameters_df':          alpha       beta
# 0    23.438255  91.966244
# 1    76.723259  39.303201
# 2     47.35665  28.534819
# 3    65.747992   32.83755
# 4    60.107579   30.67584
# ..         ...        ...
# 495        NaN        NaN
# 496        NaN        NaN
# 497        NaN        NaN
# 498        NaN        NaN
# 499        NaN        NaN
#
# [500 rows x 2 columns], 'metric_to_optimize': 'MAP', 'result_on_earlystopping_df': None, 'result_on_last': None, 'result_on_test_best': None}
# {'algorithm_name_recommender': 'DifferentLossScoresHybridRecommender', 'algorithm_name_search': 'SearchBayesianSkopt', 'cutoff_to_optimize': 10, 'exception_list': [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], 'hyperparameters_best': {'alpha': 79.6131479555512, 'beta': 79.16320148236152}, 'hyperparameters_best_index': 36, 'hyperparameters_df':          alpha       beta
# 0    23.438255  91.966244
# 1    76.723259  39.303201
# 2     47.35665  28.534819
# 3    65.747992   32.83755
# 4    60.107579   30.67584
# ..         ...        ...
# 495        NaN        NaN
# 496        NaN        NaN
# 497        NaN        NaN
# 498        NaN        NaN
# 499        NaN        NaN
#
# [500 rows x 2 columns], 'metric_to_optimize': 'MAP', 'result_on_earlystopping_df': None, 'result_on_last': None, 'result_on_test_best': None, 'result_on_test_df': None}
# {'algorithm_name_recommender': 'DifferentLossScoresHybridRecommender', 'algorithm_name_search': 'SearchBayesianSkopt', 'cutoff_to_optimize': 10, 'exception_list': [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], 'hyperparameters_best': {'alpha': 79.6131479555512, 'beta': 79.16320148236152}, 'hyperparameters_best_index': 36, 'hyperparameters_df':          alpha       beta
# 0    23.438255  91.966244
# 1    76.723259  39.303201
# 2     47.35665  28.534819
# 3    65.747992   32.83755
# 4    60.107579   30.67584
# ..         ...        ...
# 495        NaN        NaN
# 496        NaN        NaN
# 497        NaN        NaN
# 498        NaN        NaN
# 499        NaN        NaN
#
# [500 rows x 2 columns], 'metric_to_optimize': 'MAP', 'result_on_earlystopping_df': None, 'result_on_last': None, 'result_on_test_best': None, 'result_on_test_df': None, 'result_on_validation_best': {'PRECISION': 0.049660650174586214, 'PRECISION_RECALL_MIN_DEN': 0.0833139731408533, 'RECALL': 0.07810425999118492, 'MAP': 0.023993314878697575, 'MAP_MIN_DEN': 0.03955116603400915, 'MRR': 0.16590780371887207, 'NDCG': 0.07980648554087336, 'F1': 0.060716331699128614, 'HIT_RATE': 0.3388088329316874, 'ARHR_ALL_HITS': 0.19810046651818522, 'NOVELTY': 0.004342447853059679, 'AVERAGE_POPULARITY': 0.19931363358894344, 'DIVERSITY_MEAN_INTER_LIST': 0.941808521100439, 'DIVERSITY_HERFINDAHL': 0.9941785361494845, 'COVERAGE_ITEM': 0.5191985963194189, 'COVERAGE_ITEM_HIT': 0.0485575549842902, 'ITEMS_IN_GT': 0.9929815970947077, 'COVERAGE_USER': 0.976867087847414, 'COVERAGE_USER_HIT': 0.33097119796295854, 'USERS_IN_GT': 0.976867087847414, 'DIVERSITY_GINI': 0.0375485282419191, 'SHANNON_ENTROPY': 9.174022842333988, 'RATIO_DIVERSITY_HERFINDAHL': 0.9944980878214004, 'RATIO_DIVERSITY_GINI': 0.07284147438617618, 'RATIO_SHANNON_ENTROPY': 0.6786196456482689, 'RATIO_AVERAGE_POPULARITY': 3.905512135805417, 'RATIO_NOVELTY': 0.2444094880343003}}
# {'algorithm_name_recommender': 'DifferentLossScoresHybridRecommender', 'algorithm_name_search': 'SearchBayesianSkopt', 'cutoff_to_optimize': 10, 'exception_list': [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], 'hyperparameters_best': {'alpha': 79.6131479555512, 'beta': 79.16320148236152}, 'hyperparameters_best_index': 36, 'hyperparameters_df':          alpha       beta
# 0    23.438255  91.966244
# 1    76.723259  39.303201
# 2     47.35665  28.534819
# 3    65.747992   32.83755
# 4    60.107579   30.67584
# ..         ...        ...
# 495        NaN        NaN
# 496        NaN        NaN
# 497        NaN        NaN
# 498        NaN        NaN
# 499        NaN        NaN
#
# [500 rows x 2 columns], 'metric_to_optimize': 'MAP', 'result_on_earlystopping_df': None, 'result_on_last': None, 'result_on_test_best': None, 'result_on_test_df': None, 'result_on_validation_best': {'PRECISION': 0.049660650174586214, 'PRECISION_RECALL_MIN_DEN': 0.0833139731408533, 'RECALL': 0.07810425999118492, 'MAP': 0.023993314878697575, 'MAP_MIN_DEN': 0.03955116603400915, 'MRR': 0.16590780371887207, 'NDCG': 0.07980648554087336, 'F1': 0.060716331699128614, 'HIT_RATE': 0.3388088329316874, 'ARHR_ALL_HITS': 0.19810046651818522, 'NOVELTY': 0.004342447853059679, 'AVERAGE_POPULARITY': 0.19931363358894344, 'DIVERSITY_MEAN_INTER_LIST': 0.941808521100439, 'DIVERSITY_HERFINDAHL': 0.9941785361494845, 'COVERAGE_ITEM': 0.5191985963194189, 'COVERAGE_ITEM_HIT': 0.0485575549842902, 'ITEMS_IN_GT': 0.9929815970947077, 'COVERAGE_USER': 0.976867087847414, 'COVERAGE_USER_HIT': 0.33097119796295854, 'USERS_IN_GT': 0.976867087847414, 'DIVERSITY_GINI': 0.0375485282419191, 'SHANNON_ENTROPY': 9.174022842333988, 'RATIO_DIVERSITY_HERFINDAHL': 0.9944980878214004, 'RATIO_DIVERSITY_GINI': 0.07284147438617618, 'RATIO_SHANNON_ENTROPY': 0.6786196456482689, 'RATIO_AVERAGE_POPULARITY': 3.905512135805417, 'RATIO_NOVELTY': 0.2444094880343003}, 'result_on_validation_df':            PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
#     cutoff
# 0   10      0.049085                 0.082782  0.077711  0.023807    0.039461
# 1   10      0.049567                 0.083104  0.077896  0.023973    0.039537
# 2   10       0.04957                 0.083132  0.077923  0.023981    0.039547
# 3   10      0.049567                 0.083084  0.077878  0.023971    0.039531
# 4   10      0.049575                 0.083112  0.077903  0.023974    0.039537
# ...              ...                      ...       ...       ...         ...
# 495 10           NaN                      NaN       NaN       NaN         NaN
# 496 10           NaN                      NaN       NaN       NaN         NaN
# 497 10           NaN                      NaN       NaN       NaN         NaN
# 498 10           NaN                      NaN       NaN       NaN         NaN
# 499 10           NaN                      NaN       NaN       NaN         NaN
#
#                  MRR      NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
#     cutoff                                                        ...
# 0   10      0.165717  0.079464  0.060167  0.336842      0.197225  ...
# 1   10      0.165936  0.079725  0.060584  0.338268      0.198048  ...
# 2   10      0.166004  0.079746  0.060593  0.338489      0.198115  ...
# 3   10      0.165899  0.079714  0.060578  0.338243      0.198015  ...
# 4   10      0.165933  0.079729  0.060591  0.338292      0.198052  ...
# ...              ...       ...       ...       ...           ...  ...
# 495 10           NaN       NaN       NaN       NaN           NaN  ...
# 496 10           NaN       NaN       NaN       NaN           NaN  ...
# 497 10           NaN       NaN       NaN       NaN           NaN  ...
# 498 10           NaN       NaN       NaN       NaN           NaN  ...
# 499 10           NaN       NaN       NaN       NaN           NaN  ...
#
#            COVERAGE_USER COVERAGE_USER_HIT USERS_IN_GT DIVERSITY_GINI  \
#     cutoff
# 0   10          0.976867          0.329049    0.976867       0.031654
# 1   10          0.976867          0.330443    0.976867        0.03901
# 2   10          0.976867          0.330659    0.976867       0.038738
# 3   10          0.976867          0.330419    0.976867       0.039047
# 4   10          0.976867          0.330467    0.976867       0.039015
# ...                  ...               ...         ...            ...
# 495 10               NaN               NaN         NaN            NaN
# 496 10               NaN               NaN         NaN            NaN
# 497 10               NaN               NaN         NaN            NaN
# 498 10               NaN               NaN         NaN            NaN
# 499 10               NaN               NaN         NaN            NaN
#
#            SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL RATIO_DIVERSITY_GINI  \
#     cutoff
# 0   10             8.82908                   0.992744             0.061407
# 1   10            9.249291                   0.994828             0.075677
# 2   10            9.235183                   0.994769             0.075148
# 3   10            9.251114                   0.994836             0.075748
# 4   10            9.249518                   0.994829             0.075686
# ...                    ...                        ...                  ...
# 495 10                 NaN                        NaN                  NaN
# 496 10                 NaN                        NaN                  NaN
# 497 10                 NaN                        NaN                  NaN
# 498 10                 NaN                        NaN                  NaN
# 499 10                 NaN                        NaN                  NaN
#
#            RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY RATIO_NOVELTY
#     cutoff
# 0   10                  0.653104                 4.354175      0.239545
# 1   10                  0.684187                 3.808614      0.245522
# 2   10                  0.683144                 3.826384      0.245312
# 3   10                  0.684322                 3.806262       0.24555
# 4   10                  0.684204                 3.808252      0.245525
# ...                          ...                      ...           ...
# 495 10                       NaN                      NaN           NaN
# 496 10                       NaN                      NaN           NaN
# 497 10                       NaN                      NaN           NaN
# 498 10                       NaN                      NaN           NaN
# 499 10                       NaN                      NaN           NaN
#
# [500 rows x 27 columns]}
# ...
# 495 10           NaN                      NaN       NaN       NaN         NaN
# 496 10           NaN                      NaN       NaN       NaN         NaN
# 497 10           NaN                      NaN       NaN       NaN         NaN
# 498 10           NaN                      NaN       NaN       NaN         NaN
# 499 10           NaN                      NaN       NaN       NaN         NaN
#
#                  MRR      NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
#     cutoff                                                        ...
# 0   10      0.165717  0.079464  0.060167  0.336842      0.197225  ...
# 1   10      0.165936  0.079725  0.060584  0.338268      0.198048  ...
# 2   10      0.166004  0.079746  0.060593  0.338489      0.198115  ...
# 3   10      0.165899  0.079714  0.060578  0.338243      0.198015  ...
# 4   10      0.165933  0.079729  0.060591  0.338292      0.198052  ...
# ...              ...       ...       ...       ...           ...  ...
# 495 10           NaN       NaN       NaN       NaN           NaN  ...
# 496 10           NaN       NaN       NaN       NaN           NaN  ...
# 497 10           NaN       NaN       NaN       NaN           NaN  ...
# 498 10           NaN       NaN       NaN       NaN           NaN  ...
# 499 10           NaN       NaN       NaN       NaN           NaN  ...
#
#            COVERAGE_USER COVERAGE_USER_HIT USERS_IN_GT DIVERSITY_GINI  \
#     cutoff
# 0   10          0.976867          0.329049    0.976867       0.031654
# 1   10          0.976867          0.330443    0.976867        0.03901
# 2   10          0.976867          0.330659    0.976867       0.038738
# 3   10          0.976867          0.330419    0.976867       0.039047
# 4   10          0.976867          0.330467    0.976867       0.039015
# ...                  ...               ...         ...            ...
# 495 10               NaN               NaN         NaN            NaN
# 496 10               NaN               NaN         NaN            NaN
# 497 10               NaN               NaN         NaN            NaN
# 498 10               NaN               NaN         NaN            NaN
# 499 10               NaN               NaN         NaN            NaN
#
#            SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL RATIO_DIVERSITY_GINI  \
#     cutoff
# 0   10             8.82908                   0.992744             0.061407
# 1   10            9.249291                   0.994828             0.075677
# 2   10            9.235183                   0.994769             0.075148
# 3   10            9.251114                   0.994836             0.075748
# 4   10            9.249518                   0.994829             0.075686
# ...                    ...                        ...                  ...
# 495 10                 NaN                        NaN                  NaN
# 496 10                 NaN                        NaN                  NaN
# 497 10                 NaN                        NaN                  NaN
# 498 10                 NaN                        NaN                  NaN
# 499 10                 NaN                        NaN                  NaN
#
#            RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY RATIO_NOVELTY
#     cutoff
# 0   10                  0.653104                 4.354175      0.239545
# 1   10                  0.684187                 3.808614      0.245522
# 2   10                  0.683144                 3.826384      0.245312
# 3   10                  0.684322                 3.806262       0.24555
# 4   10                  0.684204                 3.808252      0.245525
# ...                          ...                      ...           ...
# 495 10                       NaN                      NaN           NaN
# 496 10                       NaN                      NaN           NaN
# 497 10                       NaN                      NaN           NaN
# 498 10                       NaN                      NaN           NaN
# 499 10                       NaN                      NaN           NaN
#
# [500 rows x 27 columns], 'time_df':         train validation test
# 0    0.043004  28.522426  NaN
# 1    0.053204  29.404525  NaN
# 2    0.037872  29.434636  NaN
# 3    0.037998  30.168877  NaN
# 4        0.04  29.255798  NaN
# ..        ...        ...  ...
# 495       NaN        NaN  NaN
# 496       NaN        NaN  NaN
# 497       NaN        NaN  NaN
# 498       NaN        NaN  NaN
# 499       NaN        NaN  NaN
#
# [500 rows x 3 columns], 'time_on_last_df':   train test
# 0   NaN  NaN, 'time_on_test_avg': 0.0, 'time_on_test_total': 0.0, 'time_on_train_avg': 0.04058873025994552, 'time_on_train_total': 1.5423717498779297, 'time_on_validation_avg': 29.140501411337603}
# {'algorithm_name_recommender': 'DifferentLossScoresHybridRecommender', 'algorithm_name_search': 'SearchBayesianSkopt', 'cutoff_to_optimize': 10, 'exception_list': [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], 'hyperparameters_best': {'alpha': 79.6131479555512, 'beta': 79.16320148236152}, 'hyperparameters_best_index': 36, 'hyperparameters_df':          alpha       beta
# 0    23.438255  91.966244
# 1    76.723259  39.303201
# 2     47.35665  28.534819
# 3    65.747992   32.83755
# 4    60.107579   30.67584
# ..         ...        ...
# 495        NaN        NaN
# 496        NaN        NaN
# 497        NaN        NaN
# 498        NaN        NaN
# 499        NaN        NaN
#
# [500 rows x 2 columns], 'metric_to_optimize': 'MAP', 'result_on_earlystopping_df': None, 'result_on_last': None, 'result_on_test_best': None, 'result_on_test_df': None, 'result_on_validation_best': {'PRECISION': 0.049660650174586214, 'PRECISION_RECALL_MIN_DEN': 0.0833139731408533, 'RECALL': 0.07810425999118492, 'MAP': 0.023993314878697575, 'MAP_MIN_DEN': 0.03955116603400915, 'MRR': 0.16590780371887207, 'NDCG': 0.07980648554087336, 'F1': 0.060716331699128614, 'HIT_RATE': 0.3388088329316874, 'ARHR_ALL_HITS': 0.19810046651818522, 'NOVELTY': 0.004342447853059679, 'AVERAGE_POPULARITY': 0.19931363358894344, 'DIVERSITY_MEAN_INTER_LIST': 0.941808521100439, 'DIVERSITY_HERFINDAHL': 0.9941785361494845, 'COVERAGE_ITEM': 0.5191985963194189, 'COVERAGE_ITEM_HIT': 0.0485575549842902, 'ITEMS_IN_GT': 0.9929815970947077, 'COVERAGE_USER': 0.976867087847414, 'COVERAGE_USER_HIT': 0.33097119796295854, 'USERS_IN_GT': 0.976867087847414, 'DIVERSITY_GINI': 0.0375485282419191, 'SHANNON_ENTROPY': 9.174022842333988, 'RATIO_DIVERSITY_HERFINDAHL': 0.9944980878214004, 'RATIO_DIVERSITY_GINI': 0.07284147438617618, 'RATIO_SHANNON_ENTROPY': 0.6786196456482689, 'RATIO_AVERAGE_POPULARITY': 3.905512135805417, 'RATIO_NOVELTY': 0.2444094880343003}, 'result_on_validation_df':            PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
#     cutoff
# 0   10      0.049085                 0.082782  0.077711  0.023807    0.039461
# 1   10      0.049567                 0.083104  0.077896  0.023973    0.039537
# 2   10       0.04957                 0.083132  0.077923  0.023981    0.039547
# 3   10      0.049567                 0.083084  0.077878  0.023971    0.039531
# 4   10      0.049575                 0.083112  0.077903  0.023974    0.039537
# ...              ...                      ...       ...       ...         ...
# 495 10           NaN                      NaN       NaN       NaN         NaN
# 496 10           NaN                      NaN       NaN       NaN         NaN
# 497 10           NaN                      NaN       NaN       NaN         NaN
# 498 10           NaN                      NaN       NaN       NaN         NaN
# 499 10           NaN                      NaN       NaN       NaN         NaN
#
#                  MRR      NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
#     cutoff                                                        ...
# 0   10      0.165717  0.079464  0.060167  0.336842      0.197225  ...
# 1   10      0.165936  0.079725  0.060584  0.338268      0.198048  ...
# 2   10      0.166004  0.079746  0.060593  0.338489      0.198115  ...
# 3   10      0.165899  0.079714  0.060578  0.338243      0.198015  ...
# 4   10      0.165933  0.079729  0.060591  0.338292      0.198052  ...
# ...              ...       ...       ...       ...           ...  ...
# 495 10           NaN       NaN       NaN       NaN           NaN  ...
# 496 10           NaN       NaN       NaN       NaN           NaN  ...
# 497 10           NaN       NaN       NaN       NaN           NaN  ...
# 498 10           NaN       NaN       NaN       NaN           NaN  ...
# 499 10           NaN       NaN       NaN       NaN           NaN  ...
#
#            COVERAGE_USER COVERAGE_USER_HIT USERS_IN_GT DIVERSITY_GINI  \
#     cutoff
# 0   10          0.976867          0.329049    0.976867       0.031654
# 1   10          0.976867          0.330443    0.976867        0.03901
# 2   10          0.976867          0.330659    0.976867       0.038738
# 3   10          0.976867          0.330419    0.976867       0.039047
# 4   10          0.976867          0.330467    0.976867       0.039015
# ...                  ...               ...         ...            ...
# 495 10               NaN               NaN         NaN            NaN
# 496 10               NaN               NaN         NaN            NaN
# 497 10               NaN               NaN         NaN            NaN
# 498 10               NaN               NaN         NaN            NaN
# 499 10               NaN               NaN         NaN            NaN
#
#            SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL RATIO_DIVERSITY_GINI  \
#     cutoff
# 0   10             8.82908                   0.992744             0.061407
# 1   10            9.249291                   0.994828             0.075677
# 2   10            9.235183                   0.994769             0.075148
# 3   10            9.251114                   0.994836             0.075748
# 4   10            9.249518                   0.994829             0.075686
# ...                    ...                        ...                  ...
# 495 10                 NaN                        NaN                  NaN
# 496 10                 NaN                        NaN                  NaN
# 497 10                 NaN                        NaN                  NaN
# 498 10                 NaN                        NaN                  NaN
# 499 10                 NaN                        NaN                  NaN
#
#            RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY RATIO_NOVELTY
#     cutoff
# 0   10                  0.653104                 4.354175      0.239545
# 1   10                  0.684187                 3.808614      0.245522
# 2   10                  0.683144                 3.826384      0.245312
# 3   10                  0.684322                 3.806262       0.24555
# 4   10                  0.684204                 3.808252      0.245525
# ...                          ...                      ...           ...
# 495 10                       NaN                      NaN           NaN
# 496 10                       NaN                      NaN           NaN
# 497 10                       NaN                      NaN           NaN
# 498 10                       NaN                      NaN           NaN
# 499 10                       NaN                      NaN           NaN
#
# [500 rows x 27 columns], 'time_df':         train validation test
# 0    0.043004  28.522426  NaN
# 1    0.053204  29.404525  NaN
# 2    0.037872  29.434636  NaN
# 3    0.037998  30.168877  NaN
# 4        0.04  29.255798  NaN
# ..        ...        ...  ...
# 495       NaN        NaN  NaN
# 496       NaN        NaN  NaN
# 497       NaN        NaN  NaN
# 498       NaN        NaN  NaN
# 499       NaN        NaN  NaN
#
# [500 rows x 3 columns], 'time_on_last_df':   train test
# 0   NaN  NaN, 'time_on_test_avg': 0.0, 'time_on_test_total': 0.0, 'time_on_train_avg': 0.04058873025994552, 'time_on_train_total': 1.5423717498779297, 'time_on_validation_avg': 29.140501411337603, 'time_on_validation_total': 1107.3390536308289}
# dict_keys(['algorithm_name_recommender', 'algorithm_name_search', 'cutoff_to_optimize', 'exception_list', 'hyperparameters_best', 'hyperparameters_best_index', 'hyperparameters_df', 'metric_to_optimize', 'result_on_earlystopping_df', 'result_on_last', 'result_on_test_best', 'result_on_test_df', 'result_on_validation_best', 'result_on_validation_df', 'time_df', 'time_on_last_df', 'time_on_test_avg', 'time_on_test_total', 'time_on_train_avg', 'time_on_train_total', 'time_on_validation_avg', 'time_on_validation_total'])

# %%
result_on_validation_df = search_metadata["result_on_validation_df"]
result_on_validation_df
# Out:
#            PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
#     cutoff
# 0   10      0.049085                 0.082782  0.077711  0.023807    0.039461
# 1   10      0.049567                 0.083104  0.077896  0.023973    0.039537
# 2   10       0.04957                 0.083132  0.077923  0.023981    0.039547
# 3   10      0.049567                 0.083084  0.077878  0.023971    0.039531
# 4   10      0.049575                 0.083112  0.077903  0.023974    0.039537
# ...              ...                      ...       ...       ...         ...
# 495 10           NaN                      NaN       NaN       NaN         NaN
# 496 10           NaN                      NaN       NaN       NaN         NaN
# 497 10           NaN                      NaN       NaN       NaN         NaN
# 498 10           NaN                      NaN       NaN       NaN         NaN
# 499 10           NaN                      NaN       NaN       NaN         NaN
#
#                  MRR      NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
#     cutoff                                                        ...
# 0   10      0.165717  0.079464  0.060167  0.336842      0.197225  ...
# 1   10      0.165936  0.079725  0.060584  0.338268      0.198048  ...
# 2   10      0.166004  0.079746  0.060593  0.338489      0.198115  ...
# 3   10      0.165899  0.079714  0.060578  0.338243      0.198015  ...
# 4   10      0.165933  0.079729  0.060591  0.338292      0.198052  ...
# ...              ...       ...       ...       ...           ...  ...
# 495 10           NaN       NaN       NaN       NaN           NaN  ...
# 496 10           NaN       NaN       NaN       NaN           NaN  ...
# 497 10           NaN       NaN       NaN       NaN           NaN  ...
# 498 10           NaN       NaN       NaN       NaN           NaN  ...
# 499 10           NaN       NaN       NaN       NaN           NaN  ...
#
#            COVERAGE_USER COVERAGE_USER_HIT USERS_IN_GT DIVERSITY_GINI  \
#     cutoff
# 0   10          0.976867          0.329049    0.976867       0.031654
# 1   10          0.976867          0.330443    0.976867        0.03901
# 2   10          0.976867          0.330659    0.976867       0.038738
# 3   10          0.976867          0.330419    0.976867       0.039047
# 4   10          0.976867          0.330467    0.976867       0.039015
# ...                  ...               ...         ...            ...
# 495 10               NaN               NaN         NaN            NaN
# 496 10               NaN               NaN         NaN            NaN
# 497 10               NaN               NaN         NaN            NaN
# 498 10               NaN               NaN         NaN            NaN
# 499 10               NaN               NaN         NaN            NaN
#
#            SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL RATIO_DIVERSITY_GINI  \
#     cutoff
# 0   10             8.82908                   0.992744             0.061407
# 1   10            9.249291                   0.994828             0.075677
# 2   10            9.235183                   0.994769             0.075148
# 3   10            9.251114                   0.994836             0.075748
# 4   10            9.249518                   0.994829             0.075686
# ...                    ...                        ...                  ...
# 495 10                 NaN                        NaN                  NaN
# 496 10                 NaN                        NaN                  NaN
# 497 10                 NaN                        NaN                  NaN
# 498 10                 NaN                        NaN                  NaN
# 499 10                 NaN                        NaN                  NaN
#
#            RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY RATIO_NOVELTY
#     cutoff
# 0   10                  0.653104                 4.354175      0.239545
# 1   10                  0.684187                 3.808614      0.245522
# 2   10                  0.683144                 3.826384      0.245312
# 3   10                  0.684322                 3.806262       0.24555
# 4   10                  0.684204                 3.808252      0.245525
# ...                          ...                      ...           ...
# 495 10                       NaN                      NaN           NaN
# 496 10                       NaN                      NaN           NaN
# 497 10                       NaN                      NaN           NaN
# 498 10                       NaN                      NaN           NaN
# 499 10                       NaN                      NaN           NaN
#
# [500 rows x 27 columns]

# %%
best_hyperparameters = search_metadata["hyperparameters_best"]
best_hyperparameters
# Out:
# {'alpha': 79.6131479555512, 'beta': 79.16320148236152}

# %%
best_result = search_metadata["result_on_validation_best"]
best_result["MAP"]
# Out:
# 0.023993314878697575
